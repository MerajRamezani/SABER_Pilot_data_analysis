# %%
import os
import pandas as pd
from pycytominer import feature_select,aggregate

# %%
# Set data input folder
# Before running notebook, download files described in README.md to this folder
input_folder = "../SABER_profiles/"

# Set output folder
output_folder = "outputs"
if not os.path.exists(output_folder):
    os.makedirs(output_folder, exist_ok=True)

# %%
# Load barcodes used in the experiment
saber_library = pd.read_csv("../common_files/SABER_Library_ngt_Included_Oligo_Sequences_Assiged.csv")
guide_list = list(saber_library['sgRNA'])
len(guide_list)
# Out:
# 2400

# %%
# Load normalized plate_level profiles, remove ghost guides, and merge 
plates = ['SABER_Plate_1','SABER_Plate_2']

pre_df_list = []
for plate in plates:
    filename = f'20240202_6W_CP498_SABER_Pilot_HeLa_SABER_only_guide_normalized_ALLBATCHES___{plate}___ALLWELLS.csv.gz'
    pre_profile_df = pd.read_csv(os.path.join(input_folder, filename))
    pre_profile_df = pre_profile_df[pre_profile_df["Metadata_Foci_Barcode_MatchedTo_Barcode"].isin(guide_list)]
    pre_df_list.append(pre_profile_df)

profile_df = pd.concat(pre_df_list)


profile_df.head()
# Out:
#   Metadata_Foci_Barcode_MatchedTo_GeneCode  \
# 0                                    AARS2
# 1                                    AARS2
# 2                                    AARS2
# 3                                    AARS2
# 4                                   AARSD1
#
#   Metadata_Foci_Barcode_MatchedTo_Barcode  Cells_AreaShape_Center_X_x  \
# 0                    AAAGGCGGCCCTCACGGCCG                      2691.9
# 1                    AGCAAACTGGGGTCGCCGCG                      2810.5
# 2                    CCAACTTCTACGCAGAACAG                      2835.8
# 3                    GCTGAGCCAGTTCAGAAGCA                      2923.9
# 4                    ACCTCCGCTCCCAATCTACC                      2770.8
#
#    Cells_AreaShape_Center_Y_x  Cytoplasm_AreaShape_Center_X_x  \
# 0                      3291.4                          2690.9
# 1                      3382.1                          2811.3
# 2                      3356.3                          2833.8
# 3                      3503.3                          2922.3
# 4                      3461.8                          2769.8
#
#    Cytoplasm_AreaShape_Center_Y_x  Nuclei_AreaShape_Center_X_x  \
# 0                          3291.5                       2688.2
# 1                          3382.6                       2820.5
# 2                          3354.9                       2832.5
# 3                          3501.2                       2933.7
# 4                          3461.8                       2767.2
#
#    Nuclei_AreaShape_Center_Y_x  Cells_AreaShape_Area  \
# 0                       3289.7             -0.425200
# 1                       3379.8             -0.046790
# 2                       3353.4             -0.519800
# 3                       3506.3             -0.037781
# 4                       3458.9              0.646950
#
#    Cells_AreaShape_BoundingBoxArea  ...  \
# 0                        -0.425680  ...
# 1                         0.002498  ...
# 2                        -0.333930  ...
# 3                        -0.072786  ...
# 4                         0.529480  ...
#
#    Nuclei_Texture_Variance_btubulin_10_02_256  \
# 0                                    -0.27762
# 1                                    -0.60813
# 2                                    -0.32481
# 3                                    -0.64861
# 4                                     0.30998
#
#    Nuclei_Texture_Variance_btubulin_10_03_256  \
# 0                                    -0.27347
# 1                                    -0.56665
# 2                                    -0.41165
# 3                                    -0.61902
# 4                                     0.38566
#
#    Nuclei_Texture_Variance_btubulin_20_00_256  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#    Nuclei_Texture_Variance_btubulin_20_01_256  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#    Nuclei_Texture_Variance_btubulin_20_02_256  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#    Nuclei_Texture_Variance_btubulin_20_03_256  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#    Nuclei_Texture_Variance_btubulin_5_00_256  \
# 0                                   -0.34762
# 1                                   -0.58488
# 2                                   -0.37323
# 3                                   -0.68133
# 4                                    0.33015
#
#    Nuclei_Texture_Variance_btubulin_5_01_256  \
# 0                                   -0.33345
# 1                                   -0.57599
# 2                                   -0.32645
# 3                                   -0.64998
# 4                                    0.24726
#
#    Nuclei_Texture_Variance_btubulin_5_02_256  \
# 0                                   -0.33496
# 1                                   -0.55988
# 2                                   -0.28932
# 3                                   -0.66432
# 4                                    0.30005
#
#    Nuclei_Texture_Variance_btubulin_5_03_256
# 0                                   -0.29404
# 1                                   -0.55576
# 2                                   -0.33573
# 3                                   -0.66757
# 4                                    0.28016
#
# [5 rows x 11043 columns]

# %%
profile_df
# Out:
#      Metadata_Foci_Barcode_MatchedTo_GeneCode  \
# 0                                       AARS2
# 1                                       AARS2
# 2                                       AARS2
# 3                                       AARS2
# 4                                      AARSD1
# ...                                       ...
# 2395                             nontargeting
# 2396                             nontargeting
# 2397                             nontargeting
# 2398                             nontargeting
# 2399                             nontargeting
#
#      Metadata_Foci_Barcode_MatchedTo_Barcode  Cells_AreaShape_Center_X_x  \
# 0                       AAAGGCGGCCCTCACGGCCG                      2691.9
# 1                       AGCAAACTGGGGTCGCCGCG                      2810.5
# 2                       CCAACTTCTACGCAGAACAG                      2835.8
# 3                       GCTGAGCCAGTTCAGAAGCA                      2923.9
# 4                       ACCTCCGCTCCCAATCTACC                      2770.8
# ...                                      ...                         ...
# 2395                    TAAGATCCGCGGGTGGCAAC                      2952.8
# 2396                    TCCCGGTTGGTGAACGATAC                      2614.7
# 2397                    TGCCGTGAAAAGACGCTGCG                      2799.3
# 2398                    TGGCCACGAATTCCGCCGCC                      2830.7
# 2399                    TTCAGCGAGTGTGACTAAGC                      2375.5
#
#       Cells_AreaShape_Center_Y_x  Cytoplasm_AreaShape_Center_X_x  \
# 0                         3291.4                          2690.9
# 1                         3382.1                          2811.3
# 2                         3356.3                          2833.8
# 3                         3503.3                          2922.3
# 4                         3461.8                          2769.8
# ...                          ...                             ...
# 2395                      3272.8                          2952.1
# 2396                      3211.4                          2615.1
# 2397                      3285.6                          2797.8
# 2398                      3510.9                          2830.1
# 2399                      3455.7                          2375.3
#
#       Cytoplasm_AreaShape_Center_Y_x  Nuclei_AreaShape_Center_X_x  \
# 0                             3291.5                       2688.2
# 1                             3382.6                       2820.5
# 2                             3354.9                       2832.5
# 3                             3501.2                       2933.7
# 4                             3461.8                       2767.2
# ...                              ...                          ...
# 2395                          3271.8                       2954.6
# 2396                          3210.9                       2617.6
# 2397                          3286.1                       2797.4
# 2398                          3509.4                       2828.4
# 2399                          3458.7                       2376.0
#
#       Nuclei_AreaShape_Center_Y_x  Cells_AreaShape_Area  \
# 0                          3289.7             -0.425200
# 1                          3379.8             -0.046790
# 2                          3353.4             -0.519800
# 3                          3506.3             -0.037781
# 4                          3458.9              0.646950
# ...                           ...                   ...
# 2395                       3274.1              0.763000
# 2396                       3209.8             -0.148980
# 2397                       3283.9             -0.290270
# 2398                       3512.5             -0.153260
# 2399                       3457.6              0.792970
#
#       Cells_AreaShape_BoundingBoxArea  ...  \
# 0                           -0.425680  ...
# 1                            0.002498  ...
# 2                           -0.333930  ...
# 3                           -0.072786  ...
# 4                            0.529480  ...
# ...                               ...  ...
# 2395                         0.847270  ...
# 2396                        -0.154530  ...
# 2397                        -0.206800  ...
# 2398                        -0.254710  ...
# 2399                         1.021500  ...
#
#       Nuclei_Texture_Variance_btubulin_10_02_256  \
# 0                                      -0.277620
# 1                                      -0.608130
# 2                                      -0.324810
# 3                                      -0.648610
# 4                                       0.309980
# ...                                          ...
# 2395                                   -0.097319
# 2396                                   -0.004332
# 2397                                   -0.321470
# 2398                                   -0.373990
# 2399                                    0.484000
#
#       Nuclei_Texture_Variance_btubulin_10_03_256  \
# 0                                      -0.273470
# 1                                      -0.566650
# 2                                      -0.411650
# 3                                      -0.619020
# 4                                       0.385660
# ...                                          ...
# 2395                                   -0.087962
# 2396                                    0.016687
# 2397                                   -0.315640
# 2398                                   -0.422790
# 2399                                    0.452350
#
#       Nuclei_Texture_Variance_btubulin_20_00_256  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ...                                          ...
# 2395                                           0
# 2396                                           0
# 2397                                           0
# 2398                                           0
# 2399                                           0
#
#       Nuclei_Texture_Variance_btubulin_20_01_256  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ...                                          ...
# 2395                                           0
# 2396                                           0
# 2397                                           0
# 2398                                           0
# 2399                                           0
#
#       Nuclei_Texture_Variance_btubulin_20_02_256  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ...                                          ...
# 2395                                           0
# 2396                                           0
# 2397                                           0
# 2398                                           0
# 2399                                           0
#
#       Nuclei_Texture_Variance_btubulin_20_03_256  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ...                                          ...
# 2395                                           0
# 2396                                           0
# 2397                                           0
# 2398                                           0
# 2399                                           0
#
#       Nuclei_Texture_Variance_btubulin_5_00_256  \
# 0                                     -0.347620
# 1                                     -0.584880
# 2                                     -0.373230
# 3                                     -0.681330
# 4                                      0.330150
# ...                                         ...
# 2395                                   0.036283
# 2396                                   0.031787
# 2397                                  -0.318210
# 2398                                  -0.431640
# 2399                                   0.184600
#
#       Nuclei_Texture_Variance_btubulin_5_01_256  \
# 0                                     -0.333450
# 1                                     -0.575990
# 2                                     -0.326450
# 3                                     -0.649980
# 4                                      0.247260
# ...                                         ...
# 2395                                  -0.033155
# 2396                                  -0.003908
# 2397                                  -0.284810
# 2398                                  -0.427470
# 2399                                   0.313500
#
#       Nuclei_Texture_Variance_btubulin_5_02_256  \
# 0                                     -0.334960
# 1                                     -0.559880
# 2                                     -0.289320
# 3                                     -0.664320
# 4                                      0.300050
# ...                                         ...
# 2395                                   0.026341
# 2396                                   0.023189
# 2397                                  -0.289590
# 2398                                  -0.399830
# 2399                                   0.300170
#
#       Nuclei_Texture_Variance_btubulin_5_03_256
# 0                                     -0.294040
# 1                                     -0.555760
# 2                                     -0.335730
# 3                                     -0.667570
# 4                                      0.280160
# ...                                         ...
# 2395                                  -0.063860
# 2396                                  -0.062283
# 2397                                  -0.331970
# 2398                                  -0.446480
# 2399                                   0.283560
#
# [4800 rows x 11043 columns]

# %%
# Remove all features from GM130 and Calnexin for comparison to Meraj's SABER profiles without ConnA and WGA
features = list(profile_df.columns)
feature_no_GM130_no_Calnexin = [feature for feature in features if 'GM130' not in feature and 'Calnexin' not in feature]
profile_df = profile_df[feature_no_GM130_no_Calnexin]
profile_df
# Out:
#      Metadata_Foci_Barcode_MatchedTo_GeneCode  \
# 0                                       AARS2
# 1                                       AARS2
# 2                                       AARS2
# 3                                       AARS2
# 4                                      AARSD1
# ...                                       ...
# 2395                             nontargeting
# 2396                             nontargeting
# 2397                             nontargeting
# 2398                             nontargeting
# 2399                             nontargeting
#
#      Metadata_Foci_Barcode_MatchedTo_Barcode  Cells_AreaShape_Center_X_x  \
# 0                       AAAGGCGGCCCTCACGGCCG                      2691.9
# 1                       AGCAAACTGGGGTCGCCGCG                      2810.5
# 2                       CCAACTTCTACGCAGAACAG                      2835.8
# 3                       GCTGAGCCAGTTCAGAAGCA                      2923.9
# 4                       ACCTCCGCTCCCAATCTACC                      2770.8
# ...                                      ...                         ...
# 2395                    TAAGATCCGCGGGTGGCAAC                      2952.8
# 2396                    TCCCGGTTGGTGAACGATAC                      2614.7
# 2397                    TGCCGTGAAAAGACGCTGCG                      2799.3
# 2398                    TGGCCACGAATTCCGCCGCC                      2830.7
# 2399                    TTCAGCGAGTGTGACTAAGC                      2375.5
#
#       Cells_AreaShape_Center_Y_x  Cytoplasm_AreaShape_Center_X_x  \
# 0                         3291.4                          2690.9
# 1                         3382.1                          2811.3
# 2                         3356.3                          2833.8
# 3                         3503.3                          2922.3
# 4                         3461.8                          2769.8
# ...                          ...                             ...
# 2395                      3272.8                          2952.1
# 2396                      3211.4                          2615.1
# 2397                      3285.6                          2797.8
# 2398                      3510.9                          2830.1
# 2399                      3455.7                          2375.3
#
#       Cytoplasm_AreaShape_Center_Y_x  Nuclei_AreaShape_Center_X_x  \
# 0                             3291.5                       2688.2
# 1                             3382.6                       2820.5
# 2                             3354.9                       2832.5
# 3                             3501.2                       2933.7
# 4                             3461.8                       2767.2
# ...                              ...                          ...
# 2395                          3271.8                       2954.6
# 2396                          3210.9                       2617.6
# 2397                          3286.1                       2797.4
# 2398                          3509.4                       2828.4
# 2399                          3458.7                       2376.0
#
#       Nuclei_AreaShape_Center_Y_x  Cells_AreaShape_Area  \
# 0                          3289.7             -0.425200
# 1                          3379.8             -0.046790
# 2                          3353.4             -0.519800
# 3                          3506.3             -0.037781
# 4                          3458.9              0.646950
# ...                           ...                   ...
# 2395                       3274.1              0.763000
# 2396                       3209.8             -0.148980
# 2397                       3283.9             -0.290270
# 2398                       3512.5             -0.153260
# 2399                       3457.6              0.792970
#
#       Cells_AreaShape_BoundingBoxArea  ...  \
# 0                           -0.425680  ...
# 1                            0.002498  ...
# 2                           -0.333930  ...
# 3                           -0.072786  ...
# 4                            0.529480  ...
# ...                               ...  ...
# 2395                         0.847270  ...
# 2396                        -0.154530  ...
# 2397                        -0.206800  ...
# 2398                        -0.254710  ...
# 2399                         1.021500  ...
#
#       Nuclei_Texture_Variance_btubulin_10_02_256  \
# 0                                      -0.277620
# 1                                      -0.608130
# 2                                      -0.324810
# 3                                      -0.648610
# 4                                       0.309980
# ...                                          ...
# 2395                                   -0.097319
# 2396                                   -0.004332
# 2397                                   -0.321470
# 2398                                   -0.373990
# 2399                                    0.484000
#
#       Nuclei_Texture_Variance_btubulin_10_03_256  \
# 0                                      -0.273470
# 1                                      -0.566650
# 2                                      -0.411650
# 3                                      -0.619020
# 4                                       0.385660
# ...                                          ...
# 2395                                   -0.087962
# 2396                                    0.016687
# 2397                                   -0.315640
# 2398                                   -0.422790
# 2399                                    0.452350
#
#       Nuclei_Texture_Variance_btubulin_20_00_256  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ...                                          ...
# 2395                                           0
# 2396                                           0
# 2397                                           0
# 2398                                           0
# 2399                                           0
#
#       Nuclei_Texture_Variance_btubulin_20_01_256  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ...                                          ...
# 2395                                           0
# 2396                                           0
# 2397                                           0
# 2398                                           0
# 2399                                           0
#
#       Nuclei_Texture_Variance_btubulin_20_02_256  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ...                                          ...
# 2395                                           0
# 2396                                           0
# 2397                                           0
# 2398                                           0
# 2399                                           0
#
#       Nuclei_Texture_Variance_btubulin_20_03_256  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ...                                          ...
# 2395                                           0
# 2396                                           0
# 2397                                           0
# 2398                                           0
# 2399                                           0
#
#       Nuclei_Texture_Variance_btubulin_5_00_256  \
# 0                                     -0.347620
# 1                                     -0.584880
# 2                                     -0.373230
# 3                                     -0.681330
# 4                                      0.330150
# ...                                         ...
# 2395                                   0.036283
# 2396                                   0.031787
# 2397                                  -0.318210
# 2398                                  -0.431640
# 2399                                   0.184600
#
#       Nuclei_Texture_Variance_btubulin_5_01_256  \
# 0                                     -0.333450
# 1                                     -0.575990
# 2                                     -0.326450
# 3                                     -0.649980
# 4                                      0.247260
# ...                                         ...
# 2395                                  -0.033155
# 2396                                  -0.003908
# 2397                                  -0.284810
# 2398                                  -0.427470
# 2399                                   0.313500
#
#       Nuclei_Texture_Variance_btubulin_5_02_256  \
# 0                                     -0.334960
# 1                                     -0.559880
# 2                                     -0.289320
# 3                                     -0.664320
# 4                                      0.300050
# ...                                         ...
# 2395                                   0.026341
# 2396                                   0.023189
# 2397                                  -0.289590
# 2398                                  -0.399830
# 2399                                   0.300170
#
#       Nuclei_Texture_Variance_btubulin_5_03_256
# 0                                     -0.294040
# 1                                     -0.555760
# 2                                     -0.335730
# 3                                     -0.667570
# 4                                      0.280160
# ...                                         ...
# 2395                                  -0.063860
# 2396                                  -0.062283
# 2397                                  -0.331970
# 2398                                  -0.446480
# 2399                                   0.283560
#
# [4800 rows x 9501 columns]

# %%
# Perform feature selection on merged profiles
profile_feature_selected_df = feature_select(
            profiles=profile_df,
            features='infer',
            samples='all',
            operation=['variance_threshold','correlation_threshold','drop_na_columns','blocklist','drop_outliers'],
            na_cutoff= 0,
            corr_threshold=0.9,
            outlier_cutoff=100
        )
profile_feature_selected_df.to_csv(os.path.join(output_folder,'20240202_6W_CP498_SABER_Pilot_HeLa_SABER_only_guide_normalized_merged_feature_select_ALLWELLS_1_2.csv.gz'))

# %%
profile_feature_selected_df
# Out:
#      Metadata_Foci_Barcode_MatchedTo_GeneCode  \
# 0                                       AARS2
# 1                                       AARS2
# 2                                       AARS2
# 3                                       AARS2
# 4                                      AARSD1
# ...                                       ...
# 2395                             nontargeting
# 2396                             nontargeting
# 2397                             nontargeting
# 2398                             nontargeting
# 2399                             nontargeting
#
#      Metadata_Foci_Barcode_MatchedTo_Barcode  \
# 0                       AAAGGCGGCCCTCACGGCCG
# 1                       AGCAAACTGGGGTCGCCGCG
# 2                       CCAACTTCTACGCAGAACAG
# 3                       GCTGAGCCAGTTCAGAAGCA
# 4                       ACCTCCGCTCCCAATCTACC
# ...                                      ...
# 2395                    TAAGATCCGCGGGTGGCAAC
# 2396                    TCCCGGTTGGTGAACGATAC
# 2397                    TGCCGTGAAAAGACGCTGCG
# 2398                    TGGCCACGAATTCCGCCGCC
# 2399                    TTCAGCGAGTGTGACTAAGC
#
#       Cells_AreaShape_BoundingBoxMaximum_Y  Cells_AreaShape_CentralMoment_0_1  \
# 0                                 -0.72350                           0.086527
# 1                                 -0.17152                           0.001845
# 2                                 -0.33226                           0.404090
# 3                                  0.58669                           0.128870
# 4                                  0.29554                          -0.421570
# ...                                    ...                                ...
# 2395                              -0.60567                          -0.060312
# 2396                              -0.93950                          -0.132260
# 2397                              -0.54274                           0.227500
# 2398                               0.71047                          -0.348130
# 2399                               0.41769                          -0.348130
#
#       Cells_AreaShape_CentralMoment_0_3  Cells_AreaShape_CentralMoment_1_0  \
# 0                             -0.345100                          -0.901010
# 1                             -0.106880                          -0.000361
# 2                              0.034043                          -0.194050
# 3                             -0.325360                           1.452300
# 4                             -0.201250                           0.367640
# ...                                 ...                                ...
# 2395                           0.315410                          -0.359710
# 2396                           0.094504                          -0.597480
# 2397                          -0.003356                          -0.165970
# 2398                           0.092173                          -0.764790
# 2399                           0.260510                          -0.553460
#
#       Cells_AreaShape_CentralMoment_1_1  Cells_AreaShape_CentralMoment_1_2  \
# 0                              0.141280                           0.577780
# 1                             -0.394080                          -0.051405
# 2                              0.171450                          -0.041717
# 3                             -0.228630                          -0.197630
# 4                              0.324740                           0.334370
# ...                                 ...                                ...
# 2395                          -1.032300                          -0.590450
# 2396                          -0.332500                           0.015295
# 2397                           0.785560                           0.183510
# 2398                           0.073275                           0.376920
# 2399                          -0.357910                           0.661060
#
#       Cells_AreaShape_CentralMoment_1_3  Cells_AreaShape_CentralMoment_2_1  \
# 0                              0.211680                          -0.475640
# 1                             -0.183930                           0.122460
# 2                              0.218850                           0.276470
# 3                             -0.028427                           0.494710
# 4                              0.362300                           0.062095
# ...                                 ...                                ...
# 2395                          -0.650870                          -0.060749
# 2396                          -0.011430                           0.092524
# 2397                           0.539330                          -0.295280
# 2398                           0.229720                          -0.689830
# 2399                          -0.050350                          -2.095900
#
#       ...  Nuclei_Texture_SumEntropy_Syto9_10_01_256  \
# 0     ...                                    0.10111
# 1     ...                                   -0.43897
# 2     ...                                   -0.09725
# 3     ...                                   -0.68643
# 4     ...                                   -0.56663
# ...   ...                                        ...
# 2395  ...                                    1.00870
# 2396  ...                                   -0.26082
# 2397  ...                                   -0.27662
# 2398  ...                                    0.26244
# 2399  ...                                    0.66103
#
#       Nuclei_Texture_SumEntropy_Syto9_10_03_256  \
# 0                                     -0.353220
# 1                                     -0.176290
# 2                                     -0.407500
# 3                                     -0.126020
# 4                                     -0.429620
# ...                                         ...
# 2395                                   0.899630
# 2396                                  -0.017144
# 2397                                  -0.483390
# 2398                                  -0.144620
# 2399                                   0.887400
#
#       Nuclei_Texture_SumEntropy_btubulin_10_01_256  \
# 0                                        -0.015718
# 1                                        -0.812680
# 2                                        -0.435290
# 3                                        -0.714230
# 4                                         0.428470
# ...                                            ...
# 2395                                      0.212820
# 2396                                      0.114110
# 2397                                     -0.479350
# 2398                                     -0.521650
# 2399                                      0.498380
#
#       Nuclei_Texture_SumVariance_NfKb_10_01_256  \
# 0                                     -0.481120
# 1                                     -0.114570
# 2                                     -0.270650
# 3                                     -0.290430
# 4                                     -0.343730
# ...                                         ...
# 2395                                   0.448720
# 2396                                  -0.088028
# 2397                                  -0.496000
# 2398                                  -0.260630
# 2399                                   0.280440
#
#       Nuclei_Texture_SumVariance_Syto9_10_00_256  \
# 0                                      -0.551010
# 1                                      -0.223580
# 2                                       0.095793
# 3                                      -0.407430
# 4                                      -1.084800
# ...                                          ...
# 2395                                    0.165270
# 2396                                    0.209160
# 2397                                   -0.483020
# 2398                                    0.221040
# 2399                                   -0.008463
#
#       Nuclei_Texture_SumVariance_Syto9_10_02_256  \
# 0                                       -0.45509
# 1                                       -0.48465
# 2                                       -0.26024
# 3                                       -0.39597
# 4                                       -0.61097
# ...                                          ...
# 2395                                     0.48795
# 2396                                    -0.51843
# 2397                                    -0.33478
# 2398                                     0.17208
# 2399                                    -0.17042
#
#       Nuclei_Texture_SumVariance_TDP43_10_01_256  \
# 0                                       0.236280
# 1                                      -0.030054
# 2                                       0.122420
# 3                                      -0.361090
# 4                                      -0.317450
# ...                                          ...
# 2395                                    0.498550
# 2396                                    0.438950
# 2397                                    0.004608
# 2398                                    0.298700
# 2399                                    0.093584
#
#       Nuclei_Texture_SumVariance_TDP43_10_02_256  \
# 0                                       0.276310
# 1                                       0.135890
# 2                                       0.044213
# 3                                      -0.100230
# 4                                      -0.148970
# ...                                          ...
# 2395                                    0.161680
# 2396                                    0.130860
# 2397                                   -0.114520
# 2398                                    0.091638
# 2399                                   -0.181770
#
#       Nuclei_Texture_SumVariance_TDP43_10_03_256  \
# 0                                       0.283320
# 1                                       0.160160
# 2                                       0.154610
# 3                                       0.116250
# 4                                       0.166720
# ...                                          ...
# 2395                                    0.110460
# 2396                                    0.222850
# 2397                                   -0.006739
# 2398                                    0.440270
# 2399                                    0.435740
#
#       Nuclei_Texture_Variance_Syto9_10_01_256
# 0                                   -0.255000
# 1                                   -0.299660
# 2                                   -0.131970
# 3                                   -0.752190
# 4                                   -0.341260
# ...                                       ...
# 2395                                 0.664950
# 2396                                -0.273710
# 2397                                -0.551740
# 2398                                 0.179850
# 2399                                -0.073603
#
# [4800 rows x 2642 columns]

# %%
# Perform median aggregation on profiles
profile_feature_selected_median_df= aggregate(
                    population_df=profile_feature_selected_df, 
                    strata=['Metadata_Foci_Barcode_MatchedTo_GeneCode' ,'Metadata_Foci_Barcode_MatchedTo_Barcode'], 
                    features='infer', 
                    operation='median' 
                    )

profile_feature_selected_median_df.to_csv(os.path.join(output_folder,'20240202_6W_CP498_SABER_Pilot_HeLa_SABER_only_guide_normalized_merged_feature_select_median_ALLWELLS_1_2.csv.gz'),index = False)

# %% [markdown]
# **Gene level aggregation**

# %%
# List files to undergo gene level aggregation
file_list = ["20240202_6W_CP498_SABER_Pilot_HeLa_SABER_only_guide_normalized_merged_feature_select_median_ALLWELLS_1_2.csv.gz"]

# Set aggregation parameters for gene level aggregation
aggregate_columns = ['Metadata_Foci_Barcode_MatchedTo_GeneCode']
aggregate_features = 'infer'
aggregate_operation = 'median'

# %%
# Perform profile aggregation
for profile_file in file_list:
    print (f"Now loading {profile_file}")
    df = pd.read_csv(os.path.join(output_folder,profile_file))
    df = df[df["Metadata_Foci_Barcode_MatchedTo_Barcode"].isin(guide_list)]

    print (f"Now aggregating.")
    gene_df = aggregate(
            population_df=df,
            strata=aggregate_columns,
            features=aggregate_features,
            operation=aggregate_operation,
            )

    print (f"Now saving aggregated file.")
    agg_file_name = f"{profile_file.split('.',1)[0]}_gene_aggregated.{profile_file.split('.',1)[1]}"
    gene_df.to_csv(os.path.join(output_folder, agg_file_name), index=False)
# Out:
# Now loading 20240202_6W_CP498_SABER_Pilot_HeLa_SABER_only_guide_normalized_merged_feature_select_median_ALLWELLS_1_2.csv.gz
# Now aggregating.
# Now saving aggregated file.

# %%
gene_df
# Out:
#     Metadata_Foci_Barcode_MatchedTo_GeneCode  \
# 0                                      AARS2
# 1                                     AARSD1
# 2                                      ABCF1
# 3                                     ABLIM1
# 4                                      ACTR2
# ..                                       ...
# 586                                    ZC3H8
# 587                                   ZC3HC1
# 588                                   ZNF131
# 589                                   ZNHIT6
# 590                             nontargeting
#
#      Cells_AreaShape_BoundingBoxMaximum_Y  Cells_AreaShape_CentralMoment_0_1  \
# 0                               -0.205588                           0.023693
# 1                                0.140995                           0.272625
# 2                                0.003170                          -0.481500
# 3                               -0.558244                           0.146947
# 4                                0.169513                           0.220674
# ..                                    ...                                ...
# 586                             -0.022036                          -0.113226
# 587                             -0.615254                           0.141876
# 588                             -0.843817                          -0.274877
# 589                              0.876942                          -0.282140
# 590                              0.015190                          -0.041136
#
#      Cells_AreaShape_CentralMoment_0_3  Cells_AreaShape_CentralMoment_1_0  \
# 0                            -0.080699                          -0.057343
# 1                             0.081797                          -0.126535
# 2                             0.561900                          -0.173627
# 3                             0.343826                           0.439982
# 4                            -0.029678                          -0.171895
# ..                                 ...                                ...
# 586                          -0.795568                           0.568145
# 587                           0.142357                           0.162268
# 588                           0.262886                          -0.040244
# 589                           0.327792                           0.742264
# 590                          -0.048846                           0.200094
#
#      Cells_AreaShape_CentralMoment_1_1  Cells_AreaShape_CentralMoment_1_2  \
# 0                             0.027962                          -0.033402
# 1                             0.398628                           0.091985
# 2                            -0.255603                          -0.225560
# 3                            -0.362965                           0.042743
# 4                            -0.167338                           0.040010
# ..                                 ...                                ...
# 586                           0.334003                           0.077486
# 587                          -0.515610                          -0.132690
# 588                          -0.003717                          -0.224979
# 589                          -0.056139                           0.279110
# 590                           0.024220                           0.069500
#
#      Cells_AreaShape_CentralMoment_1_3  Cells_AreaShape_CentralMoment_2_1  \
# 0                             0.076849                           0.083817
# 1                             0.182374                          -0.087431
# 2                             0.038623                          -0.593172
# 3                             0.052130                           0.000361
# 4                             0.099809                           0.027234
# ..                                 ...                                ...
# 586                           0.393525                          -0.132623
# 587                          -0.507639                           0.166184
# 588                          -0.078116                          -0.134581
# 589                          -0.118152                          -0.053264
# 590                           0.050155                           0.005203
#
#      Cells_AreaShape_CentralMoment_2_3  ...  \
# 0                             0.019874  ...
# 1                             0.093671  ...
# 2                            -0.541509  ...
# 3                             0.019048  ...
# 4                             0.055947  ...
# ..                                 ...  ...
# 586                          -0.094868  ...
# 587                          -0.064098  ...
# 588                           0.162277  ...
# 589                           0.059448  ...
# 590                          -0.005469  ...
#
#      Nuclei_Texture_SumEntropy_Syto9_10_01_256  \
# 0                                    -0.374615
# 1                                     0.012913
# 2                                     0.028843
# 3                                    -0.229766
# 4                                     0.811419
# ..                                         ...
# 586                                   0.498880
# 587                                  -0.169582
# 588                                   0.551580
# 589                                  -0.042642
# 590                                  -0.093287
#
#      Nuclei_Texture_SumEntropy_Syto9_10_03_256  \
# 0                                    -0.396335
# 1                                     0.236525
# 2                                     0.196578
# 3                                    -0.057305
# 4                                     0.775320
# ..                                         ...
# 586                                   0.412530
# 587                                   0.031808
# 588                                   0.147048
# 589                                   0.202350
# 590                                  -0.125683
#
#      Nuclei_Texture_SumEntropy_btubulin_10_01_256  \
# 0                                       -0.524118
# 1                                        0.168630
# 2                                        0.911600
# 3                                       -0.513901
# 4                                        1.795975
# ..                                            ...
# 586                                     -0.134758
# 587                                     -0.082787
# 588                                     -0.225332
# 589                                      0.214329
# 590                                      0.013850
#
#      Nuclei_Texture_SumVariance_NfKb_10_01_256  \
# 0                                    -0.329375
# 1                                    -0.124790
# 2                                    -0.900122
# 3                                    -0.058773
# 4                                     3.684625
# ..                                         ...
# 586                                  -0.626308
# 587                                   0.600818
# 588                                  -0.133487
# 589                                   0.318047
# 590                                   0.002387
#
#      Nuclei_Texture_SumVariance_Syto9_10_00_256  \
# 0                                     -0.350120
# 1                                      0.316453
# 2                                      0.418750
# 3                                      0.061827
# 4                                      1.246983
# ..                                          ...
# 586                                   -0.189309
# 587                                   -0.468210
# 588                                    0.067398
# 589                                    0.205272
# 590                                   -0.022202
#
#      Nuclei_Texture_SumVariance_Syto9_10_02_256  \
# 0                                     -0.381850
# 1                                     -0.026575
# 2                                      0.236627
# 3                                      0.064997
# 4                                      1.286035
# ..                                          ...
# 586                                    0.330240
# 587                                   -0.218002
# 588                                    0.159290
# 589                                    0.238812
# 590                                   -0.114684
#
#      Nuclei_Texture_SumVariance_TDP43_10_01_256  \
# 0                                      0.041402
# 1                                      0.181426
# 2                                      0.870753
# 3                                     -0.202675
# 4                                     -0.034865
# ..                                          ...
# 586                                    0.609622
# 587                                    0.324425
# 588                                   -0.020956
# 589                                   -0.006842
# 590                                    0.243080
#
#      Nuclei_Texture_SumVariance_TDP43_10_02_256  \
# 0                                      0.030863
# 1                                     -0.096967
# 2                                      1.086597
# 3                                     -0.077290
# 4                                      1.250970
# ..                                          ...
# 586                                    0.347368
# 587                                    0.425944
# 588                                   -0.197158
# 589                                    0.274765
# 590                                    0.151522
#
#      Nuclei_Texture_SumVariance_TDP43_10_03_256  \
# 0                                      0.048960
# 1                                      0.064950
# 2                                      0.983365
# 3                                      0.115830
# 4                                      0.133793
# ..                                          ...
# 586                                    0.625757
# 587                                    0.546220
# 588                                   -0.020906
# 589                                    0.162147
# 590                                    0.305783
#
#      Nuclei_Texture_Variance_Syto9_10_01_256
# 0                                  -0.370085
# 1                                   0.160856
# 2                                   0.154630
# 3                                  -0.101946
# 4                                   1.596575
# ..                                       ...
# 586                                 0.307787
# 587                                -0.371775
# 588                                 0.112614
# 589                                 0.281501
# 590                                -0.016045
#
# [591 rows x 2641 columns]
