# %%
import os
import pandas as pd
import numpy as np
import dask.dataframe as dd
from numpy import dot
from numpy.linalg import norm
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import scipy.stats as ss
import json
import pathlib
from pycytominer import aggregate, normalize

# %matplotlib inline

# %%
# Set data input folder
# Download files described in README.md to this folder
input_folder = "inputs"

# Set output folder, subfolder
output_folder = "outputs"
if not os.path.exists(output_folder):
    os.makedirs(output_folder, exist_ok=True)
if not os.path.exists(os.path.join(output_folder,"figure_panels")):
    os.makedirs(os.path.join(output_folder,"figure_panels"), exist_ok=True)

# %%
# Load barcodes used in experiment
guide_df = pd.read_csv("SABER_Library_ngt_Included_Oligo_Sequences_Assiged.csv")
all_guides_list = list(guide_df.iloc[:,4].unique())

count_df = pd.read_csv(os.path.join(output_folder,'HeLa_SABER_screen_CP_arm_cell_count.csv.gz'))
count_df = count_df.rename(columns={'Metadata_Foci_Barcode_MatchedTo_GeneCode':'gene','Metadata_Foci_Barcode_MatchedTo_Barcode':'barcode'})
count_df['n_guides'] = np.nan

count_df
# Out:
#          gene               barcode  Cell_Count  n_guides
# 0       AP3S1  CTTGCAGAAATGGTGATGGG        8659       NaN
# 1     NDUFAF7  GACACCTTTCATATACACTG        7872       NaN
# 2        PER1  CCAACACGAAGGCTACCTTG        7450       NaN
# 3       YWHAH  TTTCGATCTTCATTGGAGAG        6627       NaN
# 4         XPC  GCTGTAGAGACAATACCAGC        6620       NaN
# ...       ...                   ...         ...       ...
# 2395     ADAR  TTCTTGTAGGGTGAACACCG          29       NaN
# 2396     DHX8  CCCAGGTCGAACATATCCAG          29       NaN
# 2397    RPS4X  TGTACATCGTATTACACCTG          28       NaN
# 2398     RPS6  AGTGGTGGGAACGACAAACA          18       NaN
# 2399  SUV39H1  CGTGGAGGACGTGTACACCG          18       NaN
#
# [2400 rows x 4 columns]

# %%
count_df_1000 = count_df.query('Cell_Count > 1000')
all_guides_list_1000 = list(count_df_1000.barcode.unique())
for guide in all_guides_list_1000:
    gene = list(count_df_1000.loc[count_df_1000['barcode']== guide,'gene'])[0]
    df_temp = count_df_1000.query('gene == @gene')
    count_df_1000.loc[count_df_1000['barcode']== guide,'n_guides'] = len(df_temp)
    
count_df_1000_4_guides = count_df_1000.query('n_guides >= 4')
selected_genes_list = list(count_df_1000_4_guides.gene.unique())
selected_guides_list = list(count_df_1000_4_guides.barcode.unique())
count_df_1000_4_guides
# Out:
#           gene               barcode  Cell_Count  n_guides
# 0        AP3S1  CTTGCAGAAATGGTGATGGG        8659       4.0
# 1      NDUFAF7  GACACCTTTCATATACACTG        7872       4.0
# 2         PER1  CCAACACGAAGGCTACCTTG        7450       4.0
# 4          XPC  GCTGTAGAGACAATACCAGC        6620       4.0
# 6          MNT  CGTCCAATCTGAGCGTGCTG        6532       4.0
# ...        ...                   ...         ...       ...
# 1561    SLC9B2  GGGCGTGTAATTCATTCCTG        1019       4.0
# 1562  CYB561A3  GCAGGCGAAGAGGAAGACAG        1019       4.0
# 1565     MRPL2  TTGTTGATGAGGGTCCCCAC        1017       4.0
# 1567     MRNIP  TTCAGCCAGCGACTCTCTGA        1014       4.0
# 1573     RPL22  CAAGATCACCGTGACATCCG        1003       4.0
#
# [835 rows x 4 columns]

# %%
cp498_guide_profiles_df = pd.read_csv('20240202_6W_CP498_SABER_Pilot_HeLa_guide_normalized_merged_feature_select_median_ALLWELLS_cp.csv.gz')
selected_features = list(cp498_guide_profiles_df.columns)
len(selected_features)
# Out:
# 605

# %%
# Load and subset the single-cell profiles per plate for M059K plates
plates = ['CP_Plate_1','CP_Plate_2']
chunksize = 10 ** 5

df_plate_list = []
for plate in plates:
    filename = f'20240202_6W_CP498_SABER_Pilot_HeLa_single_cell_normalized_ALLBATCHES___{plate}___ALLWELLS.csv.gz' 
    chunks = []
    with pd.read_csv(filename ,usecols=selected_features ,chunksize=chunksize) as reader:
        for chunk in reader:
            sub_chunk = chunk[chunk['Metadata_Foci_Barcode_MatchedTo_GeneCode'].isin(selected_genes_list)]
            chunks.append(sub_chunk)
            print(chunk.shape,f'of plate {plate}')
            print(sub_chunk.shape,f'of plate {plate}')
    df = pd.concat(chunks)
    #df.to_csv(os.path.join(output_folder,f'20240202_6W_CP498_SABER_Pilot_HeLa_single_cell_profiles_ALLBATCHES___{plate}_ALLWELLS.csv.gz'),index = False)
    df_plate_list.append(df)

single_cell_df = pd.concat(df_plate_list)
#metadata_df.to_csv(os.path.join(output_folder,'CP498_CP_single_cell_metadata.csv.gz'),index = False)
single_cell_df
# Out:
# (100000, 605) of plate CP_Plate_1
# (51483, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (51355, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (50916, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (51121, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (50922, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (51052, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (50910, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (51214, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (51378, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (50645, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (50530, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (51107, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (50789, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (51020, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (51379, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (50971, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (51056, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (51749, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (50932, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_1
# (50779, 605) of plate CP_Plate_1
# (54497, 605) of plate CP_Plate_1
# (27753, 605) of plate CP_Plate_1
# (100000, 605) of plate CP_Plate_2
# (51170, 605) of plate CP_Plate_2
# (100000, 605) of plate CP_Plate_2
# (51062, 605) of plate CP_Plate_2
# (100000, 605) of plate CP_Plate_2
# (50918, 605) of plate CP_Plate_2
# (100000, 605) of plate CP_Plate_2
# (51687, 605) of plate CP_Plate_2
# (100000, 605) of plate CP_Plate_2
# (51286, 605) of plate CP_Plate_2
# (100000, 605) of plate CP_Plate_2
# (50389, 605) of plate CP_Plate_2
# (100000, 605) of plate CP_Plate_2
# (51219, 605) of plate CP_Plate_2
# (100000, 605) of plate CP_Plate_2
# (51754, 605) of plate CP_Plate_2
# (100000, 605) of plate CP_Plate_2
# (51267, 605) of plate CP_Plate_2
# (100000, 605) of plate CP_Plate_2
# (51443, 605) of plate CP_Plate_2
# (100000, 605) of plate CP_Plate_2
# (51137, 605) of plate CP_Plate_2
# (100000, 605) of plate CP_Plate_2
# (50806, 605) of plate CP_Plate_2
# (100000, 605) of plate CP_Plate_2
# (50742, 605) of plate CP_Plate_2
# (100000, 605) of plate CP_Plate_2
# (51260, 605) of plate CP_Plate_2
# (100000, 605) of plate CP_Plate_2
# (50798, 605) of plate CP_Plate_2
# (100000, 605) of plate CP_Plate_2
# (50998, 605) of plate CP_Plate_2
# (100000, 605) of plate CP_Plate_2
# (51689, 605) of plate CP_Plate_2
# (100000, 605) of plate CP_Plate_2
# (51097, 605) of plate CP_Plate_2
# (100000, 605) of plate CP_Plate_2
# (51430, 605) of plate CP_Plate_2
# (36854, 605) of plate CP_Plate_2
# (18815, 605) of plate CP_Plate_2
#         Metadata_Foci_Barcode_MatchedTo_GeneCode  \
# 0                                          WFDC8
# 2                                           ALG6
# 4                                            XPC
# 5                                          SIRPD
# 8                                          LTA4H
# ...                                          ...
# 1936846                                    RUFY2
# 1936847                                      SP3
# 1936850                                     CDX4
# 1936852                                     COG4
# 1936853                                     GDI2
#
#         Metadata_Foci_Barcode_MatchedTo_Barcode  \
# 0                          TGCACACCCTTCAAATACAG
# 2                          CTATGATAAGCTGTAAGAGG
# 4                          AGTTTGAGACATATCTTCGG
# 5                          TGTCACAGACTGTATCAACT
# 8                          AAGTTACAAGGGATCGCCAA
# ...                                         ...
# 1936846                    CGGCCCGCTCGCCTTACCCA
# 1936847                    AGGAGCACCAAACCGATGGG
# 1936850                    TCTTGCGCATCCATGCATAG
# 1936852                    GCTGTATACGAACGGCTCTG
# 1936853                    GAAGGGAGCTTTGTCTATAA
#
#          Cells_AreaShape_BoundingBoxMinimum_X  \
# 0                                     0.33910
# 2                                    -0.26959
# 4                                    -0.61313
# 5                                     0.87960
# 8                                     0.11475
# ...                                       ...
# 1936846                              -0.77208
# 1936847                              -1.31570
# 1936850                               1.36510
# 1936852                               1.57700
# 1936853                               0.71646
#
#          Cells_AreaShape_BoundingBoxMinimum_Y  \
# 0                                     -1.7174
# 2                                     -1.7174
# 4                                     -1.7174
# 5                                     -1.7174
# 8                                     -1.7174
# ...                                       ...
# 1936846                                1.7342
# 1936847                                1.7243
# 1936850                                1.7367
# 1936852                                1.7457
# 1936853                                1.7531
#
#          Cells_AreaShape_CentralMoment_0_1  Cells_AreaShape_CentralMoment_0_3  \
# 0                                 0.072071                           0.121760
# 2                                 0.158580                          -0.001102
# 4                                 0.088938                          -0.014271
# 5                                -0.256020                          -0.053752
# 8                                -0.732640                          -0.035928
# ...                                    ...                                ...
# 1936846                           0.118910                          -0.000102
# 1936847                           0.646250                          -0.054271
# 1936850                           0.124890                           0.013005
# 1936852                           0.158370                          -0.000343
# 1936853                          -0.080788                           0.004154
#
#          Cells_AreaShape_CentralMoment_1_0  Cells_AreaShape_CentralMoment_1_2  \
# 0                                 0.101720                          -0.101790
# 2                                -0.052358                          -0.012074
# 4                                -0.033471                           0.011853
# 5                                 0.176030                          -0.093815
# 8                                -0.539440                           0.087959
# ...                                    ...                                ...
# 1936846                          -0.141150                           0.002974
# 1936847                          -1.191800                           1.080000
# 1936850                          -0.469450                          -0.016478
# 1936852                           0.266780                           0.028289
# 1936853                          -0.075391                           0.021587
#
#          Cells_AreaShape_CentralMoment_1_3  Cells_AreaShape_CentralMoment_2_1  \
# 0                                -0.021398                          -0.006896
# 2                                 0.000843                          -0.003387
# 4                                 0.001063                           0.024355
# 5                                 0.005095                           0.002981
# 8                                -0.034513                          -0.041095
# ...                                    ...                                ...
# 1936846                          -0.000674                          -0.007706
# 1936847                          -0.004139                           0.032866
# 1936850                          -0.001007                          -0.055665
# 1936852                          -0.000643                           0.000672
# 1936853                          -0.000496                           0.003179
#
#          ...  Nuclei_Texture_InfoMeas1_Mito_5_01_256  \
# 0        ...                               -3.944500
# 2        ...                               -0.200910
# 4        ...                                0.029975
# 5        ...                               -0.564290
# 8        ...                               -1.178200
# ...      ...                                     ...
# 1936846  ...                                0.033391
# 1936847  ...                               -0.129320
# 1936850  ...                                0.059044
# 1936852  ...                               -1.945300
# 1936853  ...                                0.011489
#
#          Nuclei_Texture_InfoMeas1_Mito_5_03_256  \
# 0                                      -5.40000
# 2                                      -0.17471
# 4                                      -2.08050
# 5                                      -0.80006
# 8                                      -1.01840
# ...                                         ...
# 1936846                                -0.39784
# 1936847                                 0.76133
# 1936850                                 0.33514
# 1936852                                -3.93760
# 1936853                                 0.14993
#
#          Nuclei_Texture_InfoMeas1_WGA_10_00_256  \
# 0                                       1.44820
# 2                                       1.44820
# 4                                      -3.35290
# 5                                      -0.39363
# 8                                      -0.57479
# ...                                         ...
# 1936846                                 0.48434
# 1936847                                -0.20525
# 1936850                                 0.52958
# 1936852                                -2.78170
# 1936853                                 0.14238
#
#          Nuclei_Texture_InfoMeas1_WGA_5_00_256  \
# 0                                     -1.32950
# 2                                      0.13018
# 4                                     -0.96654
# 5                                     -0.68601
# 8                                      0.30901
# ...                                        ...
# 1936846                                0.58864
# 1936847                                0.71030
# 1936850                               -0.38818
# 1936852                               -2.11560
# 1936853                                0.27703
#
#          Nuclei_Texture_InfoMeas1_WGA_5_02_256  \
# 0                                     -5.69840
# 2                                     -0.60213
# 4                                     -1.84710
# 5                                     -0.75781
# 8                                     -2.07730
# ...                                        ...
# 1936846                                0.63853
# 1936847                                0.37983
# 1936850                                0.59306
# 1936852                               -2.53660
# 1936853                                0.59878
#
#          Nuclei_Texture_InfoMeas2_DAPI_Painting_10_03_256  \
# 0                                                -8.01470
# 2                                                -8.01470
# 4                                                 0.67144
# 5                                                 0.73562
# 8                                                 0.41309
# ...                                                   ...
# 1936846                                           0.52346
# 1936847                                          -1.07220
# 1936850                                           0.35518
# 1936852                                           0.62336
# 1936853                                           0.55766
#
#          Nuclei_Texture_InfoMeas2_Mito_5_02_256  \
# 0                                       2.06720
# 2                                       0.55768
# 4                                       0.95267
# 5                                       1.17840
# 8                                       1.47580
# ...                                         ...
# 1936846                                -0.61321
# 1936847                                -0.38453
# 1936850                                -0.54053
# 1936852                                 2.22880
# 1936853                                -0.60742
#
#          Nuclei_Texture_InfoMeas2_Phalloidin_5_00_256  \
# 0                                            1.204500
# 2                                           -0.048279
# 4                                            0.607510
# 5                                            1.095900
# 8                                            0.099404
# ...                                               ...
# 1936846                                     -0.511080
# 1936847                                     -0.834690
# 1936850                                      0.510890
# 1936852                                      2.104200
# 1936853                                     -0.166600
#
#          Nuclei_Texture_SumAverage_DAPI_Painting_10_03_256  \
# 0                                                -4.306900
# 2                                                -4.306900
# 4                                                -1.026600
# 5                                                -0.350350
# 8                                                 0.238900
# ...                                                    ...
# 1936846                                           0.379420
# 1936847                                          -0.226630
# 1936850                                          -0.330620
# 1936852                                          -0.231270
# 1936853                                          -0.048359
#
#          Nuclei_Texture_SumVariance_Mito_10_03_256
# 0                                         -0.30137
# 2                                         -0.30137
# 4                                         -0.29255
# 5                                         -0.12051
# 8                                         -0.15957
# ...                                            ...
# 1936846                                   -0.15437
# 1936847                                   -0.20246
# 1936850                                   -0.12476
# 1936852                                    0.78589
# 1936853                                   -0.13987
#
# [2040028 rows x 605 columns]

# %%
subsample_ns = [100,200,300,400,500,750,1000]
subsample_dfs_dictionary = {} 
for n in subsample_ns:
    df_list_n = []
    for guide in selected_guides_list:
        df_temp = single_cell_df.query('Metadata_Foci_Barcode_MatchedTo_Barcode == @guide')
        if len(df_temp)<n:
            continue
        df_temp_sample = df_temp.sample(n=n,random_state=42)
        df_list_n.append(df_temp_sample)
    df_n = pd.concat(df_list_n)
    aggregate_df_n = aggregate(
        population_df=df_n,
        strata=['Metadata_Foci_Barcode_MatchedTo_GeneCode','Metadata_Foci_Barcode_MatchedTo_Barcode'],
        features='infer',
        operation='median'
    )
    subsample_dfs_dictionary[n]=aggregate_df_n
    aggregate_df_n.to_csv(f'CP498_cp_arm_subsampled_aggregated_{n}_cells.csv',index=False)
    print(f'profiles at {n} representation level are aggregated.')
subsample_dfs_dictionary[subsample_ns[0]]
# Out:
# profiles at 100 representation level are aggregated.
# profiles at 200 representation level are aggregated.
# profiles at 300 representation level are aggregated.
# profiles at 400 representation level are aggregated.
# profiles at 500 representation level are aggregated.
# profiles at 750 representation level are aggregated.
# profiles at 1000 representation level are aggregated.
#     Metadata_Foci_Barcode_MatchedTo_GeneCode  \
# 0                                      AARS2
# 1                                      AARS2
# 2                                      AARS2
# 3                                      AARS2
# 4                                      AIMP1
# ..                                       ...
# 830                             nontargeting
# 831                             nontargeting
# 832                             nontargeting
# 833                             nontargeting
# 834                             nontargeting
#
#     Metadata_Foci_Barcode_MatchedTo_Barcode  \
# 0                      AAAGGCGGCCCTCACGGCCG
# 1                      AGCAAACTGGGGTCGCCGCG
# 2                      CCAACTTCTACGCAGAACAG
# 3                      GCTGAGCCAGTTCAGAAGCA
# 4                      AACCAATTCGAAGATCCAGA
# ..                                      ...
# 830                    TAACGCGCATATCTGAACAC
# 831                    TAAGATCCGCGGGTGGCAAC
# 832                    TCCCGGTTGGTGAACGATAC
# 833                    TGCCGTGAAAAGACGCTGCG
# 834                    TGGCCACGAATTCCGCCGCC
#
#      Cells_AreaShape_BoundingBoxMinimum_X  \
# 0                               -0.047145
# 1                                0.198930
# 2                                0.087979
# 3                                0.291935
# 4                                0.302620
# ..                                    ...
# 830                             -0.094090
# 831                              0.027071
# 832                              0.394875
# 833                              0.128245
# 834                             -0.107380
#
#      Cells_AreaShape_BoundingBoxMinimum_Y  Cells_AreaShape_CentralMoment_0_1  \
# 0                               -0.152930                           0.040650
# 1                                0.273430                          -0.022194
# 2                                0.123690                           0.014783
# 3                                0.067807                          -0.001653
# 4                               -0.154275                           0.045312
# ..                                    ...                                ...
# 830                              0.148590                          -0.023213
# 831                             -0.119107                          -0.023405
# 832                             -0.275650                           0.005013
# 833                              0.001784                           0.092241
# 834                             -0.197445                          -0.070025
#
#      Cells_AreaShape_CentralMoment_0_3  Cells_AreaShape_CentralMoment_1_0  \
# 0                             0.000431                           0.002315
# 1                            -0.000468                          -0.043343
# 2                            -0.000691                           0.024470
# 3                            -0.000353                           0.004862
# 4                            -0.002396                          -0.004807
# ..                                 ...                                ...
# 830                           0.001302                           0.023935
# 831                          -0.000103                          -0.026474
# 832                           0.000181                           0.026173
# 833                           0.000393                           0.044811
# 834                          -0.000845                           0.004273
#
#      Cells_AreaShape_CentralMoment_1_2  Cells_AreaShape_CentralMoment_1_3  \
# 0                            -0.001583                          -0.000704
# 1                            -0.002329                          -0.000586
# 2                            -0.002760                          -0.000669
# 3                            -0.001431                          -0.000852
# 4                             0.004524                          -0.000765
# ..                                 ...                                ...
# 830                          -0.007333                          -0.000748
# 831                          -0.006450                          -0.000638
# 832                          -0.001456                          -0.000672
# 833                           0.012793                          -0.000479
# 834                          -0.008930                          -0.000907
#
#      Cells_AreaShape_CentralMoment_2_1  ...  \
# 0                             0.000459  ...
# 1                            -0.000171  ...
# 2                             0.002763  ...
# 3                             0.000900  ...
# 4                             0.001852  ...
# ..                                 ...  ...
# 830                          -0.002855  ...
# 831                           0.001053  ...
# 832                          -0.001233  ...
# 833                           0.000540  ...
# 834                          -0.000021  ...
#
#      Nuclei_Texture_InfoMeas1_Mito_5_01_256  \
# 0                                  0.404965
# 1                                  0.208935
# 2                                  0.179655
# 3                                  0.291645
# 4                                  0.389535
# ..                                      ...
# 830                                0.258360
# 831                                0.402965
# 832                                0.460730
# 833                                0.119015
# 834                                0.393415
#
#      Nuclei_Texture_InfoMeas1_Mito_5_03_256  \
# 0                                  0.327245
# 1                                  0.366555
# 2                                  0.242345
# 3                                  0.177760
# 4                                  0.408290
# ..                                      ...
# 830                                0.154755
# 831                                0.440150
# 832                                0.260260
# 833                                0.239120
# 834                                0.362230
#
#      Nuclei_Texture_InfoMeas1_WGA_10_00_256  \
# 0                                  0.350820
# 1                                  0.086311
# 2                                  0.233825
# 3                                  0.302325
# 4                                  0.271500
# ..                                      ...
# 830                                0.200245
# 831                                0.432065
# 832                                0.350655
# 833                                0.193815
# 834                                0.356135
#
#      Nuclei_Texture_InfoMeas1_WGA_5_00_256  \
# 0                                 0.453590
# 1                                 0.350640
# 2                                 0.300650
# 3                                 0.161355
# 4                                 0.191115
# ..                                     ...
# 830                               0.190030
# 831                               0.484275
# 832                               0.402675
# 833                               0.289735
# 834                               0.491790
#
#      Nuclei_Texture_InfoMeas1_WGA_5_02_256  \
# 0                                 0.419500
# 1                                 0.303310
# 2                                 0.230180
# 3                                 0.251795
# 4                                 0.318315
# ..                                     ...
# 830                               0.208015
# 831                               0.402780
# 832                               0.334665
# 833                               0.271410
# 834                               0.376895
#
#      Nuclei_Texture_InfoMeas2_DAPI_Painting_10_03_256  \
# 0                                            0.310230
# 1                                            0.300890
# 2                                            0.334535
# 3                                            0.055112
# 4                                            0.309415
# ..                                                ...
# 830                                          0.282450
# 831                                          0.216080
# 832                                          0.301145
# 833                                          0.189620
# 834                                          0.326620
#
#      Nuclei_Texture_InfoMeas2_Mito_5_02_256  \
# 0                                 -0.206460
# 1                                 -0.028083
# 2                                 -0.013408
# 3                                 -0.054536
# 4                                 -0.158910
# ..                                      ...
# 830                               -0.049942
# 831                               -0.282695
# 832                               -0.195360
# 833                               -0.057307
# 834                               -0.289930
#
#      Nuclei_Texture_InfoMeas2_Phalloidin_5_00_256  \
# 0                                       -0.368325
# 1                                       -0.082801
# 2                                       -0.105311
# 3                                        0.087383
# 4                                       -0.067606
# ..                                            ...
# 830                                      0.068923
# 831                                     -0.331700
# 832                                     -0.209815
# 833                                     -0.050156
# 834                                     -0.413715
#
#      Nuclei_Texture_SumAverage_DAPI_Painting_10_03_256  \
# 0                                            -0.136825
# 1                                            -0.126630
# 2                                            -0.286515
# 3                                            -0.357265
# 4                                            -0.076102
# ..                                                 ...
# 830                                          -0.169075
# 831                                          -0.248305
# 832                                          -0.321630
# 833                                          -0.219660
# 834                                          -0.043227
#
#      Nuclei_Texture_SumVariance_Mito_10_03_256
# 0                                    -0.172900
# 1                                    -0.182655
# 2                                    -0.164750
# 3                                    -0.172460
# 4                                    -0.156590
# ..                                         ...
# 830                                  -0.161100
# 831                                  -0.179080
# 832                                  -0.167840
# 833                                  -0.162470
# 834                                  -0.167945
#
# [835 rows x 605 columns]

# %%
# Load the subsampled, aggregated profiles from the previous step if you are starting from here
# These files are not stored in the Github repository - see the README for download instructions
'''
subsample_ns = [100,200,300,400,500,750,1000]
subsample_dfs_dictionary = {} 
for n in subsample_ns:
    aggregate_df_n = pd.read_csv(f'CP498_cp_arm_subsampled_aggregated_{n}_cells.csv')
    subsample_dfs_dictionary[n] = aggregate_df_n

# %%
def cosine_to_df(df_temp, cosine_array, i):
    cosine_list = cosine_array[i]
    gene_list = list(df_temp.index)
    cosine_df = pd.DataFrame(index=gene_list)
    cosine_df['cosine'] = cosine_list
    cosine_df = cosine_df.sort_values('cosine',ascending=False)   
    return cosine_df

def ap_from_cosine_df(cosine_df,gene,n=10):    
    #print(cosine_df.iloc[:20])
    index_list = list(cosine_df.index)
    boolean = [1 if  i == gene else 0 for i in index_list ]
    grades_list=[]
    for i in range(2,n+2):
        pre_grade = sum(boolean[1:i])/(i-1)
        grades_list.append(pre_grade*boolean[i-1])
    return sum(grades_list)/3

def calculate_map(df_guide, gene):
    df_temp = df_guide.query("Metadata_Foci_Barcode_MatchedTo_GeneCode == 'nontargeting' | Metadata_Foci_Barcode_MatchedTo_GeneCode == @gene")
    df_temp = df_temp.drop(['Metadata_Foci_Barcode_MatchedTo_Barcode'],axis=1)
    df_temp = df_temp.set_index("Metadata_Foci_Barcode_MatchedTo_GeneCode")
    #print(df_temp)
    ap_list = []
    cosine_array = cosine_similarity(df_temp)
    for guide in range(4):
        cosine_df = cosine_to_df(df_temp, cosine_array, guide)
        #print(cosine_df[:10])
        guide_ap = ap_from_cosine_df(cosine_df,gene,10)
        ap_list.append(guide_ap)
    return np.mean(ap_list)

# %%
# calculate the mAP values
rep_results = {}
for n in subsample_ns:
    genes_list = list(subsample_dfs_dictionary[n].Metadata_Foci_Barcode_MatchedTo_GeneCode.unique())
    map_list = []
    for i in range(len(genes_list)):
        gene = genes_list[i]
        gene_map = calculate_map(subsample_dfs_dictionary[n], gene)
        map_list.append([gene, gene_map])
    rep_results[n] = map_list

# %%
ys = []
for n in subsample_ns:
    y = [i[1] for i in rep_results[n] if i[1]]
    ys.append(np.mean(y))

mpl.rc('axes', linewidth=0.7)
mpl.rc('ytick', labelsize=12)
mpl.rc('xtick', labelsize=12)

fig, ax = plt.subplots(figsize=(7,5))

ax = sns.lineplot(x=subsample_ns, y=ys, errorbar=None, style=1, markers=True, legend=False)
ax.set_title('',size=14)
ax.set_xlabel('Guide level representation',size=12)
ax.set_ylabel('Average mAP',size=12)
ax.set_xticks(range(0,1001,100))

# draw reference lines for screen data
#plt.axvline(x=117, color = 'orange', linestyle='dashed', label='A549')
#plt.text(160,.58,'-- A549',color='orange')
#plt.axvline(x=125, color = 'red', linestyle='dashed', label='HeLa DMEM')
#plt.text(160,.56,'-- HeLa DMEM',color='red')
#plt.axvline(x=93, color = 'brown', linestyle='dashed', label='HeLa HPLM')
#plt.text(160,.6,'-- HeLa HPLM',color = 'brown')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
fig.savefig(os.path.join(output_folder,'figure_panels','CP498_cp_arm_subsample_average_mAP.png'),dpi = 300,bbox_inches='tight')
plt.show()
