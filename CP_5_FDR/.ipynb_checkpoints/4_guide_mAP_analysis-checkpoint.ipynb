# %%
import pandas as pd
import numpy as np
from numpy import dot
from numpy.linalg import norm
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns
from functools import reduce
from scipy.spatial import distance
import pathlib
import os
from sklearn.decomposition import PCA
import json
import random
from random import sample

random.seed(30)

# %%
# Set data input folder
input_folder = "inputs"

# Set output folder, subfolder
output_folder = "outputs"
if not os.path.exists(output_folder):
    os.makedirs(output_folder, exist_ok=True)

# %%
# Import the guide-level profiles
df_guide = pd.read_csv("outputs/20230601_6W_CP469_SABER_Pilot_M059K_guide_normalized_feature_select_median_merged_ALLBATCHES___ALLWELLS_cp_features.csv.gz")
# Subset the nontargeting guide profiles 
df_nontargeting = df_guide.query("Metadata_Foci_Barcode_MatchedTo_GeneCode == 'nontargeting'")

# Load hits from the hit calling process
whole_cell_hits = pd.read_csv('outputs/M059K_plate_level_median_per_feat_sig_genes_5_FDR_whole_cell_hits_32_controls.csv')
comp_spec_hits = pd.read_csv('outputs/M059K_plate_level_median_per_feat_sig_genes_5_FDR_compartment_specific_hits_32_controls.csv')
all_hits = pd.concat([whole_cell_hits,comp_spec_hits])
hit_list = list(comp_spec_hits.Gene) + list(whole_cell_hits.Gene)
whole_cell_hit_list = list(whole_cell_hits.Gene)
comp_spec_hit_list = list(comp_spec_hits.Gene)

# list non hit genes
all_genes_list = list(df_guide.Metadata_Foci_Barcode_MatchedTo_GeneCode.unique())
all_genes_list.remove("nontargeting")
non_hit_list = [gene for gene in all_genes_list if gene not in hit_list]
print("All genes:",len(all_genes_list),"non-hit genes",len(non_hit_list),'Whole cell hits',len(whole_cell_hit_list),'Compartment hits',len(comp_spec_hit_list))
# Out:
# All genes: 590 non-hit genes 329 Whole cell hits 203 Compartment hits 58

# %%
def calculate_mean_similarity(cosine_array):
    total_sum = 0
    for i in range(4):
        similarities = cosine_array[i]
        target_sum = 0
        for j in range(4):
            target_sum += similarities[j]  
        target_mean = ((target_sum-1)/3)
        total_sum += target_mean

    total_mean = total_sum / 4
    return total_mean

hit_guide_sim_list =[]
for i in range(len(whole_cell_hit_list)):
    df_temp = df_guide.query("Metadata_Foci_Barcode_MatchedTo_GeneCode == @whole_cell_hit_list[@i]")
    df_temp = df_temp.drop(['Metadata_Foci_Barcode_MatchedTo_Barcode'],axis=1)
    df_temp = df_temp.set_index("Metadata_Foci_Barcode_MatchedTo_GeneCode")
    cosine_array = cosine_similarity(df_temp)
    hit_guide_sim = calculate_mean_similarity(cosine_array)
    hit_guide_sim_list.append(hit_guide_sim)
average_cosine_distance = sum(hit_guide_sim_list)/len(hit_guide_sim_list)
print('Average cosine distance: ',average_cosine_distance)
# Out:
# Average cosine distance:  0.1499613576630236

# %%
df_temp = df_guide.query("Metadata_Foci_Barcode_MatchedTo_GeneCode == @whole_cell_hit_list[130]")
df_temp = df_temp.drop(['Metadata_Foci_Barcode_MatchedTo_Barcode'],axis=1)
df_temp = df_temp.set_index("Metadata_Foci_Barcode_MatchedTo_GeneCode")
cosine_array = cosine_similarity(df_temp)
print(whole_cell_hit_list[5])
cosine_array[0]
# Out:
# APEX1
# array([ 1.        , -0.03879113, -0.04860413,  0.06872586])

# %%
def cosine_to_grade(df_temp, cosine_array, i):
    cosine_list = cosine_array[i]
    gene_list = list(df_temp.index)
    cosine_df = pd.DataFrame(index=gene_list)
    cosine_df['cosine'] = cosine_list
    cosine_df = cosine_df.sort_values('cosine',ascending=False)
    grade_list = list(cosine_df.iloc[0:4].index)
    grade = (grade_list.count(gene)-1)/3
    return grade
    
def grade_single_gene(df_guide, gene):
    df_temp = df_guide.query("Metadata_Foci_Barcode_MatchedTo_GeneCode == 'nontargeting' | Metadata_Foci_Barcode_MatchedTo_GeneCode == @gene")
    df_temp = df_temp.drop(['Metadata_Foci_Barcode_MatchedTo_Barcode'],axis=1)
    df_temp = df_temp.set_index("Metadata_Foci_Barcode_MatchedTo_GeneCode")
    cosine_array = cosine_similarity(df_temp)
    #grade = cosine_to_grade(df_temp, cosine_array)
    grade_total = 0
    for i in range(4):
        grade = cosine_to_grade(df_temp, cosine_array, i)
        grade_total+=grade
    mAP = grade_total/4
    return mAP

grade_list = []
for i in range(len(whole_cell_hit_list)):
    gene = whole_cell_hit_list[i]
    print(f"Calculating mean average precision for gene: {gene}")
    gene_grade = grade_single_gene(df_guide, gene)
    grade_list.append(gene_grade)
    
sum(grade_list)/len(grade_list)
# Out:
# Calculating mean average precision for gene: ABCF1
# Calculating mean average precision for gene: ACTR2
# Calculating mean average precision for gene: ACTR3
# Calculating mean average precision for gene: ALG8
# Calculating mean average precision for gene: ANAPC10
# Calculating mean average precision for gene: APEX1
# Calculating mean average precision for gene: ARF4
# Calculating mean average precision for gene: ARNTL
# Calculating mean average precision for gene: ARPC2
# Calculating mean average precision for gene: ARPC3
# Calculating mean average precision for gene: ARPC4
# Calculating mean average precision for gene: ATF4
# Calculating mean average precision for gene: ATIC
# Calculating mean average precision for gene: ATP6V0A1
# Calculating mean average precision for gene: ATP6V0B
# Calculating mean average precision for gene: ATP6V0C
# Calculating mean average precision for gene: ATP6V0D1
# Calculating mean average precision for gene: ATP6V1H
# Calculating mean average precision for gene: BAK1
# Calculating mean average precision for gene: BANP
# Calculating mean average precision for gene: BCL2L1
# Calculating mean average precision for gene: CALM1
# Calculating mean average precision for gene: CANX
# Calculating mean average precision for gene: CASC3
# Calculating mean average precision for gene: CCT4
# Calculating mean average precision for gene: CDC6
# Calculating mean average precision for gene: CDK13
# Calculating mean average precision for gene: CDK4
# Calculating mean average precision for gene: CENPK
# Calculating mean average precision for gene: CHM
# Calculating mean average precision for gene: CHMP6
# Calculating mean average precision for gene: CIAO1
# Calculating mean average precision for gene: COG3
# Calculating mean average precision for gene: COG4
# Calculating mean average precision for gene: COPA
# Calculating mean average precision for gene: COPZ1
# Calculating mean average precision for gene: COX4I1
# Calculating mean average precision for gene: COX8A
# Calculating mean average precision for gene: CPSF1
# Calculating mean average precision for gene: CPSF3
# Calculating mean average precision for gene: CPSF6
# Calculating mean average precision for gene: CPT1B
# Calculating mean average precision for gene: DCTN5
# Calculating mean average precision for gene: DDX6
# Calculating mean average precision for gene: DHX8
# Calculating mean average precision for gene: DLG1
# Calculating mean average precision for gene: DNM1L
# Calculating mean average precision for gene: DOCK2
# Calculating mean average precision for gene: DPH2
# Calculating mean average precision for gene: DRG2
# Calculating mean average precision for gene: EEF1G
# Calculating mean average precision for gene: EEF2
# Calculating mean average precision for gene: EIF2B1
# Calculating mean average precision for gene: EIF2B2
# Calculating mean average precision for gene: EIF2B4
# Calculating mean average precision for gene: EIF2B5
# Calculating mean average precision for gene: EIF2S3
# Calculating mean average precision for gene: EIF3E
# Calculating mean average precision for gene: EIF3H
# Calculating mean average precision for gene: EIF3L
# Calculating mean average precision for gene: EIF4A1
# Calculating mean average precision for gene: EIF4B
# Calculating mean average precision for gene: EIF4E
# Calculating mean average precision for gene: EIF4EBP1
# Calculating mean average precision for gene: EIF5
# Calculating mean average precision for gene: ENO1
# Calculating mean average precision for gene: FAM193A
# Calculating mean average precision for gene: FGFR1
# Calculating mean average precision for gene: FIP1L1
# Calculating mean average precision for gene: GDI2
# Calculating mean average precision for gene: GINS1
# Calculating mean average precision for gene: GLE1
# Calculating mean average precision for gene: GOLGA2
# Calculating mean average precision for gene: HAUS1
# Calculating mean average precision for gene: HAUS3
# Calculating mean average precision for gene: HDAC2
# Calculating mean average precision for gene: HDAC3
# Calculating mean average precision for gene: HSP90B1
# Calculating mean average precision for gene: ISL1
# Calculating mean average precision for gene: ITGAV
# Calculating mean average precision for gene: ITGB1
# Calculating mean average precision for gene: ITGB5
# Calculating mean average precision for gene: ITPK1
# Calculating mean average precision for gene: KCTD10
# Calculating mean average precision for gene: KDM1A
# Calculating mean average precision for gene: KDM5A
# Calculating mean average precision for gene: KIF5B
# Calculating mean average precision for gene: KPNA6
# Calculating mean average precision for gene: LAMTOR3
# Calculating mean average precision for gene: LTA4H
# Calculating mean average precision for gene: M6PR
# Calculating mean average precision for gene: MCM3
# Calculating mean average precision for gene: MCM5
# Calculating mean average precision for gene: MED12
# Calculating mean average precision for gene: MED17
# Calculating mean average precision for gene: MED9
# Calculating mean average precision for gene: MLH1
# Calculating mean average precision for gene: MNT
# Calculating mean average precision for gene: MRPL27
# Calculating mean average precision for gene: MRPL37
# Calculating mean average precision for gene: MRPL57
# Calculating mean average precision for gene: MRPS31
# Calculating mean average precision for gene: MTIF2
# Calculating mean average precision for gene: MTOR
# Calculating mean average precision for gene: MYC
# Calculating mean average precision for gene: NBR1
# Calculating mean average precision for gene: NCOR1
# Calculating mean average precision for gene: NDUFA2
# Calculating mean average precision for gene: NDUFA4
# Calculating mean average precision for gene: NEDD8
# Calculating mean average precision for gene: NPEPPS
# Calculating mean average precision for gene: NUP93
# Calculating mean average precision for gene: OIP5
# Calculating mean average precision for gene: PACS2
# Calculating mean average precision for gene: PAFAH1B1
# Calculating mean average precision for gene: PAK2
# Calculating mean average precision for gene: PAPSS2
# Calculating mean average precision for gene: PFDN5
# Calculating mean average precision for gene: PHB2
# Calculating mean average precision for gene: PIP4K2A
# Calculating mean average precision for gene: POGZ
# Calculating mean average precision for gene: POLD2
# Calculating mean average precision for gene: PPP1CC
# Calculating mean average precision for gene: PPP2R2A
# Calculating mean average precision for gene: PPWD1
# Calculating mean average precision for gene: PRIM2
# Calculating mean average precision for gene: PRPF38A
# Calculating mean average precision for gene: PSMA1
# Calculating mean average precision for gene: PSMA2
# Calculating mean average precision for gene: PSMA3
# Calculating mean average precision for gene: PSMB1
# Calculating mean average precision for gene: PSMB5
# Calculating mean average precision for gene: PSMC1
# Calculating mean average precision for gene: PSMC6
# Calculating mean average precision for gene: PSMD13
# Calculating mean average precision for gene: PSMD5
# Calculating mean average precision for gene: RAB11B
# Calculating mean average precision for gene: RAC1
# Calculating mean average precision for gene: RELA
# Calculating mean average precision for gene: RFC3
# Calculating mean average precision for gene: RFTN1
# Calculating mean average precision for gene: RHEB
# Calculating mean average precision for gene: RNPS1
# Calculating mean average precision for gene: RPL19
# Calculating mean average precision for gene: RPL29
# Calculating mean average precision for gene: RPL32
# Calculating mean average precision for gene: RPL35
# Calculating mean average precision for gene: RPL36
# Calculating mean average precision for gene: RPL37
# Calculating mean average precision for gene: RPL39
# Calculating mean average precision for gene: RPL4
# Calculating mean average precision for gene: RPL5
# Calculating mean average precision for gene: RPN1
# Calculating mean average precision for gene: RPS12
# Calculating mean average precision for gene: RPS16
# Calculating mean average precision for gene: RPS20
# Calculating mean average precision for gene: RPS24
# Calculating mean average precision for gene: RPS3
# Calculating mean average precision for gene: RPS6
# Calculating mean average precision for gene: RPS6KA1
# Calculating mean average precision for gene: RPS8
# Calculating mean average precision for gene: SAP130
# Calculating mean average precision for gene: SEC11C
# Calculating mean average precision for gene: SEH1L
# Calculating mean average precision for gene: SEPHS2
# Calculating mean average precision for gene: SF3B1
# Calculating mean average precision for gene: SF3B4
# Calculating mean average precision for gene: SFPQ
# Calculating mean average precision for gene: SH3BP4
# Calculating mean average precision for gene: SHOC2
# Calculating mean average precision for gene: SMARCAD1
# Calculating mean average precision for gene: SNRPB
# Calculating mean average precision for gene: SP3
# Calculating mean average precision for gene: SRD5A1
# Calculating mean average precision for gene: SRSF1
# Calculating mean average precision for gene: STRIP1
# Calculating mean average precision for gene: STX10
# Calculating mean average precision for gene: SYMPK
# Calculating mean average precision for gene: TAF5L
# Calculating mean average precision for gene: TARDBP
# Calculating mean average precision for gene: TECPR1
# Calculating mean average precision for gene: TIMELESS
# Calculating mean average precision for gene: TMED10
# Calculating mean average precision for gene: TMED2
# Calculating mean average precision for gene: TOMM22
# Calculating mean average precision for gene: TOMM7
# Calculating mean average precision for gene: TPT1
# Calculating mean average precision for gene: TRAPPC1
# Calculating mean average precision for gene: TRAPPC3
# Calculating mean average precision for gene: TRAPPC4
# Calculating mean average precision for gene: TUBB4B
# Calculating mean average precision for gene: TXNRD1
# Calculating mean average precision for gene: UBA6
# Calculating mean average precision for gene: UBC
# Calculating mean average precision for gene: UBQLN2
# Calculating mean average precision for gene: UCP2
# Calculating mean average precision for gene: UFM1
# Calculating mean average precision for gene: UQCRB
# Calculating mean average precision for gene: USP1
# Calculating mean average precision for gene: VPS41
# Calculating mean average precision for gene: WDR83
# Calculating mean average precision for gene: ZNF131
# Calculating mean average precision for gene: ZNHIT6
# 0.251231527093596

# %%
grade_list = []
for i in range(len(comp_spec_hit_list)):
    gene = comp_spec_hit_list[i]
    print(f"Calculating mean average precision for gene: {gene}")
    gene_grade = grade_single_gene(df_guide, gene)
    grade_list.append(gene_grade)
    
sum(grade_list)/len(grade_list)
# Out:
# Calculating mean average precision for gene: ALG5
# Calculating mean average precision for gene: ATL2
# Calculating mean average precision for gene: CBX3
# Calculating mean average precision for gene: CLGN
# Calculating mean average precision for gene: COA3
# Calculating mean average precision for gene: CRKL
# Calculating mean average precision for gene: DDA1
# Calculating mean average precision for gene: DHX35
# Calculating mean average precision for gene: DVL1
# Calculating mean average precision for gene: DYNLL1
# Calculating mean average precision for gene: EIF3C
# Calculating mean average precision for gene: EIF4A2
# Calculating mean average precision for gene: ETFB
# Calculating mean average precision for gene: EXOC3
# Calculating mean average precision for gene: EXOSC3
# Calculating mean average precision for gene: GAPVD1
# Calculating mean average precision for gene: GSR
# Calculating mean average precision for gene: HAUS8
# Calculating mean average precision for gene: HYOU1
# Calculating mean average precision for gene: IGF2BP1
# Calculating mean average precision for gene: KPNA1
# Calculating mean average precision for gene: MAPK3
# Calculating mean average precision for gene: MCM10
# Calculating mean average precision for gene: MCM3AP
# Calculating mean average precision for gene: MFN2
# Calculating mean average precision for gene: MRPL1
# Calculating mean average precision for gene: MRPL13
# Calculating mean average precision for gene: MRPL28
# Calculating mean average precision for gene: MRPL33
# Calculating mean average precision for gene: MRPL49
# Calculating mean average precision for gene: MRPS9
# Calculating mean average precision for gene: NDUFS2
# Calculating mean average precision for gene: PABPN1
# Calculating mean average precision for gene: PHAX
# Calculating mean average precision for gene: PLRG1
# Calculating mean average precision for gene: PRMT5
# Calculating mean average precision for gene: PSMA4
# Calculating mean average precision for gene: PSMD9
# Calculating mean average precision for gene: RABL3
# Calculating mean average precision for gene: RBM17
# Calculating mean average precision for gene: REEP5
# Calculating mean average precision for gene: RFC5
# Calculating mean average precision for gene: RPL36A
# Calculating mean average precision for gene: RPS4X
# Calculating mean average precision for gene: SART1
# Calculating mean average precision for gene: SDHB
# Calculating mean average precision for gene: SDHD
# Calculating mean average precision for gene: SETDB1
# Calculating mean average precision for gene: SLC35A1
# Calculating mean average precision for gene: SSR1
# Calculating mean average precision for gene: SSR4
# Calculating mean average precision for gene: ST3GAL1
# Calculating mean average precision for gene: STT3A
# Calculating mean average precision for gene: TSR1
# Calculating mean average precision for gene: UBE2D3
# Calculating mean average precision for gene: UPF3B
# Calculating mean average precision for gene: USP33
# Calculating mean average precision for gene: WARS2
# 0.1235632183908046

# %%
grade_list = []
for i in range(len(non_hit_list)):
    gene = non_hit_list[i]
    print(f"Calculating mean average precision for gene: {gene}")
    gene_grade = grade_single_gene(df_guide, gene)
    grade_list.append(gene_grade)
    
sum(grade_list)/len(grade_list)
# Out:
# Calculating mean average precision for gene: AARS2
# Calculating mean average precision for gene: AARSD1
# Calculating mean average precision for gene: ABLIM1
# Calculating mean average precision for gene: ADAR
# Calculating mean average precision for gene: AIMP1
# Calculating mean average precision for gene: AIMP2
# Calculating mean average precision for gene: ALG13
# Calculating mean average precision for gene: ALG6
# Calculating mean average precision for gene: ALKBH7
# Calculating mean average precision for gene: ANKRD13A
# Calculating mean average precision for gene: ANXA2
# Calculating mean average precision for gene: AP3S1
# Calculating mean average precision for gene: ARFGAP3
# Calculating mean average precision for gene: ARPC1A
# Calculating mean average precision for gene: ARPC1B
# Calculating mean average precision for gene: ARPC5
# Calculating mean average precision for gene: ARPC5L
# Calculating mean average precision for gene: ATF3
# Calculating mean average precision for gene: ATG14
# Calculating mean average precision for gene: ATP6V0E1
# Calculating mean average precision for gene: ATP6V0E2
# Calculating mean average precision for gene: ATRIP
# Calculating mean average precision for gene: ATXN3
# Calculating mean average precision for gene: AURKB
# Calculating mean average precision for gene: BARD1
# Calculating mean average precision for gene: BEX3
# Calculating mean average precision for gene: BOD1
# Calculating mean average precision for gene: BOD1L1
# Calculating mean average precision for gene: BRAP
# Calculating mean average precision for gene: CAT
# Calculating mean average precision for gene: CCNI
# Calculating mean average precision for gene: CD5L
# Calculating mean average precision for gene: CD93
# Calculating mean average precision for gene: CDC23
# Calculating mean average precision for gene: CDC73
# Calculating mean average precision for gene: CDCA2
# Calculating mean average precision for gene: CDK2AP2
# Calculating mean average precision for gene: CDX4
# Calculating mean average precision for gene: CEACAM4
# Calculating mean average precision for gene: CEBPG
# Calculating mean average precision for gene: CELA3A
# Calculating mean average precision for gene: CHMP4B
# Calculating mean average precision for gene: CHP1
# Calculating mean average precision for gene: CIT
# Calculating mean average precision for gene: CLCN3
# Calculating mean average precision for gene: CLDN17
# Calculating mean average precision for gene: CNOT6
# Calculating mean average precision for gene: CNOT7
# Calculating mean average precision for gene: COA5
# Calculating mean average precision for gene: COMMD1
# Calculating mean average precision for gene: COPG2
# Calculating mean average precision for gene: COQ10A
# Calculating mean average precision for gene: COQ10B
# Calculating mean average precision for gene: COQ5
# Calculating mean average precision for gene: COX14
# Calculating mean average precision for gene: COX17
# Calculating mean average precision for gene: COX18
# Calculating mean average precision for gene: COX7B
# Calculating mean average precision for gene: COX7C
# Calculating mean average precision for gene: CRY1
# Calculating mean average precision for gene: CSE1L
# Calculating mean average precision for gene: CXCL9
# Calculating mean average precision for gene: CYB561A3
# Calculating mean average precision for gene: CYB5A
# Calculating mean average precision for gene: CYCS
# Calculating mean average precision for gene: DARS2
# Calculating mean average precision for gene: DCAF15
# Calculating mean average precision for gene: DEFB119
# Calculating mean average precision for gene: DEFB127
# Calculating mean average precision for gene: DEFB128
# Calculating mean average precision for gene: DEFB131A
# Calculating mean average precision for gene: DENND4B
# Calculating mean average precision for gene: DNA2
# Calculating mean average precision for gene: DNAJC24
# Calculating mean average precision for gene: DONSON
# Calculating mean average precision for gene: DPM3
# Calculating mean average precision for gene: DVL3
# Calculating mean average precision for gene: ECI1
# Calculating mean average precision for gene: ECSIT
# Calculating mean average precision for gene: EIF2AK4
# Calculating mean average precision for gene: EIF2B3
# Calculating mean average precision for gene: EIF2D
# Calculating mean average precision for gene: EIF4EBP2
# Calculating mean average precision for gene: EML3
# Calculating mean average precision for gene: EPC1
# Calculating mean average precision for gene: ERCC2
# Calculating mean average precision for gene: ESRP2
# Calculating mean average precision for gene: ESX1
# Calculating mean average precision for gene: ESYT1
# Calculating mean average precision for gene: ETFA
# Calculating mean average precision for gene: EYA4
# Calculating mean average precision for gene: FAM71A
# Calculating mean average precision for gene: FANCI
# Calculating mean average precision for gene: FNBP1L
# Calculating mean average precision for gene: FOLR1
# Calculating mean average precision for gene: GABARAPL1
# Calculating mean average precision for gene: GCN1
# Calculating mean average precision for gene: GOLGA1
# Calculating mean average precision for gene: GORASP1
# Calculating mean average precision for gene: GPR119
# Calculating mean average precision for gene: GSPT1
# Calculating mean average precision for gene: HAUS4
# Calculating mean average precision for gene: HDGFL2
# Calculating mean average precision for gene: HIBCH
# Calculating mean average precision for gene: HIF1A
# Calculating mean average precision for gene: HLA-B
# Calculating mean average precision for gene: HMCES
# Calculating mean average precision for gene: HSFY1
# Calculating mean average precision for gene: IARS2
# Calculating mean average precision for gene: ID2
# Calculating mean average precision for gene: IFNA16
# Calculating mean average precision for gene: IFT22
# Calculating mean average precision for gene: IMPACT
# Calculating mean average precision for gene: INO80
# Calculating mean average precision for gene: INTS14
# Calculating mean average precision for gene: INTS7
# Calculating mean average precision for gene: ITFG2
# Calculating mean average precision for gene: JOSD1
# Calculating mean average precision for gene: JTB
# Calculating mean average precision for gene: KATNA1
# Calculating mean average precision for gene: KIF20B
# Calculating mean average precision for gene: KRTAP22-1
# Calculating mean average precision for gene: LAMP1
# Calculating mean average precision for gene: LAMTOR1
# Calculating mean average precision for gene: LCE2B
# Calculating mean average precision for gene: LHX9
# Calculating mean average precision for gene: MAD1L1
# Calculating mean average precision for gene: MAGOH
# Calculating mean average precision for gene: MAGOHB
# Calculating mean average precision for gene: MAP1LC3B
# Calculating mean average precision for gene: MAP1S
# Calculating mean average precision for gene: MBL2
# Calculating mean average precision for gene: MCOLN1
# Calculating mean average precision for gene: MDC1
# Calculating mean average precision for gene: MED1
# Calculating mean average precision for gene: MED8
# Calculating mean average precision for gene: MFSD3
# Calculating mean average precision for gene: MMP27
# Calculating mean average precision for gene: MORF4L2
# Calculating mean average precision for gene: MRNIP
# Calculating mean average precision for gene: MRPL18
# Calculating mean average precision for gene: MRPL2
# Calculating mean average precision for gene: MRPL24
# Calculating mean average precision for gene: MRPL36
# Calculating mean average precision for gene: MRPL55
# Calculating mean average precision for gene: MRPS15
# Calculating mean average precision for gene: MRPS18C
# Calculating mean average precision for gene: MRPS26
# Calculating mean average precision for gene: MRPS5
# Calculating mean average precision for gene: MSH6
# Calculating mean average precision for gene: MSTO1
# Calculating mean average precision for gene: MVB12A
# Calculating mean average precision for gene: MYO1B
# Calculating mean average precision for gene: MYO1E
# Calculating mean average precision for gene: NAMPT
# Calculating mean average precision for gene: NCSTN
# Calculating mean average precision for gene: NDEL1
# Calculating mean average precision for gene: NDUFA10
# Calculating mean average precision for gene: NDUFA11
# Calculating mean average precision for gene: NDUFA12
# Calculating mean average precision for gene: NDUFA7
# Calculating mean average precision for gene: NDUFAF6
# Calculating mean average precision for gene: NDUFAF7
# Calculating mean average precision for gene: NDUFB3
# Calculating mean average precision for gene: NDUFB7
# Calculating mean average precision for gene: NDUFC2
# Calculating mean average precision for gene: NDUFS3
# Calculating mean average precision for gene: NFKBIA
# Calculating mean average precision for gene: NHEJ1
# Calculating mean average precision for gene: NHLH2
# Calculating mean average precision for gene: NMD3
# Calculating mean average precision for gene: NPRL2
# Calculating mean average precision for gene: NPRL3
# Calculating mean average precision for gene: NPVF
# Calculating mean average precision for gene: NSMCE4A
# Calculating mean average precision for gene: NUDT12
# Calculating mean average precision for gene: NUP188
# Calculating mean average precision for gene: OAZ1
# Calculating mean average precision for gene: OPRPN
# Calculating mean average precision for gene: OR10H3
# Calculating mean average precision for gene: OR2G3
# Calculating mean average precision for gene: OR4C5
# Calculating mean average precision for gene: OR7D4
# Calculating mean average precision for gene: OST4
# Calculating mean average precision for gene: OSTC
# Calculating mean average precision for gene: PAIP1
# Calculating mean average precision for gene: PAPSS1
# Calculating mean average precision for gene: PDCD6IP
# Calculating mean average precision for gene: PEF1
# Calculating mean average precision for gene: PER1
# Calculating mean average precision for gene: PEX13
# Calculating mean average precision for gene: PEX16
# Calculating mean average precision for gene: PEX19
# Calculating mean average precision for gene: PINK1
# Calculating mean average precision for gene: PMAIP1
# Calculating mean average precision for gene: PML
# Calculating mean average precision for gene: PPA2
# Calculating mean average precision for gene: PPIF
# Calculating mean average precision for gene: PPP1CA
# Calculating mean average precision for gene: PPP1R10
# Calculating mean average precision for gene: PPP2R3C
# Calculating mean average precision for gene: PRDX6
# Calculating mean average precision for gene: PRR30
# Calculating mean average precision for gene: PRY2
# Calculating mean average precision for gene: PSEN1
# Calculating mean average precision for gene: PSMA5
# Calculating mean average precision for gene: PSMB10
# Calculating mean average precision for gene: PSMB8
# Calculating mean average precision for gene: PSMD10
# Calculating mean average precision for gene: PSMD7
# Calculating mean average precision for gene: PSME4
# Calculating mean average precision for gene: PSMF1
# Calculating mean average precision for gene: RAB10
# Calculating mean average precision for gene: RAB11FIP3
# Calculating mean average precision for gene: RAB27A
# Calculating mean average precision for gene: RAB2B
# Calculating mean average precision for gene: RAB3GAP1
# Calculating mean average precision for gene: RAB3IP
# Calculating mean average precision for gene: RAB4A
# Calculating mean average precision for gene: RBP1
# Calculating mean average precision for gene: RBPMS
# Calculating mean average precision for gene: RCC1
# Calculating mean average precision for gene: REXO4
# Calculating mean average precision for gene: RFPL3
# Calculating mean average precision for gene: RHOB
# Calculating mean average precision for gene: RIF1
# Calculating mean average precision for gene: RPL18
# Calculating mean average precision for gene: RPL22
# Calculating mean average precision for gene: RPL22L1
# Calculating mean average precision for gene: RPL26L1
# Calculating mean average precision for gene: RPL35A
# Calculating mean average precision for gene: RPL39L
# Calculating mean average precision for gene: RPS10-NUDT3
# Calculating mean average precision for gene: RPS27L
# Calculating mean average precision for gene: RPS6KA3
# Calculating mean average precision for gene: RPS6KB2
# Calculating mean average precision for gene: RRAGC
# Calculating mean average precision for gene: RSU1
# Calculating mean average precision for gene: RUFY2
# Calculating mean average precision for gene: SASS6
# Calculating mean average precision for gene: SCARB2
# Calculating mean average precision for gene: SCGB1D1
# Calculating mean average precision for gene: SCLY
# Calculating mean average precision for gene: SCNM1
# Calculating mean average precision for gene: SCO1
# Calculating mean average precision for gene: SEC11A
# Calculating mean average precision for gene: SELENOV
# Calculating mean average precision for gene: SF3B3
# Calculating mean average precision for gene: SIRPD
# Calculating mean average precision for gene: SLC15A4
# Calculating mean average precision for gene: SLC25A27
# Calculating mean average precision for gene: SLC25A6
# Calculating mean average precision for gene: SLC27A2
# Calculating mean average precision for gene: SLC46A1
# Calculating mean average precision for gene: SLC9A6
# Calculating mean average precision for gene: SLC9B2
# Calculating mean average precision for gene: SMG7
# Calculating mean average precision for gene: SMG9
# Calculating mean average precision for gene: SMR3A
# Calculating mean average precision for gene: SNAP47
# Calculating mean average precision for gene: SNRNP27
# Calculating mean average precision for gene: SNRNP48
# Calculating mean average precision for gene: SNTN
# Calculating mean average precision for gene: SPAST
# Calculating mean average precision for gene: SPATA48
# Calculating mean average precision for gene: SPCS1
# Calculating mean average precision for gene: SPIDR
# Calculating mean average precision for gene: SPO11
# Calculating mean average precision for gene: SPRR2G
# Calculating mean average precision for gene: SREBF1
# Calculating mean average precision for gene: SRPRB
# Calculating mean average precision for gene: SSR2
# Calculating mean average precision for gene: SSR3
# Calculating mean average precision for gene: ST3GAL4
# Calculating mean average precision for gene: STAG1
# Calculating mean average precision for gene: STAM
# Calculating mean average precision for gene: STT3B
# Calculating mean average precision for gene: STX5
# Calculating mean average precision for gene: STX6
# Calculating mean average precision for gene: STX7
# Calculating mean average precision for gene: SUGP1
# Calculating mean average precision for gene: SUPT7L
# Calculating mean average precision for gene: SUV39H1
# Calculating mean average precision for gene: SYNCRIP
# Calculating mean average precision for gene: SYTL4
# Calculating mean average precision for gene: TBC1D23
# Calculating mean average precision for gene: TBL1Y
# Calculating mean average precision for gene: TCERG1
# Calculating mean average precision for gene: TCIRG1
# Calculating mean average precision for gene: TERF2IP
# Calculating mean average precision for gene: TFAP2D
# Calculating mean average precision for gene: THAP11
# Calculating mean average precision for gene: TMEM106B
# Calculating mean average precision for gene: TMEM126B
# Calculating mean average precision for gene: TMEM165
# Calculating mean average precision for gene: TMEM201
# Calculating mean average precision for gene: TOE1
# Calculating mean average precision for gene: TOMM20
# Calculating mean average precision for gene: TOMM40
# Calculating mean average precision for gene: TOMM5
# Calculating mean average precision for gene: TOMM6
# Calculating mean average precision for gene: TRAM1
# Calculating mean average precision for gene: TSC1
# Calculating mean average precision for gene: TSFM
# Calculating mean average precision for gene: TSR2
# Calculating mean average precision for gene: TUBA1A
# Calculating mean average precision for gene: TUBG2
# Calculating mean average precision for gene: UBAP1
# Calculating mean average precision for gene: UBE2T
# Calculating mean average precision for gene: UPF3A
# Calculating mean average precision for gene: UQCR10
# Calculating mean average precision for gene: UQCRHL
# Calculating mean average precision for gene: UQCRQ
# Calculating mean average precision for gene: USB1
# Calculating mean average precision for gene: USP5
# Calculating mean average precision for gene: VDAC2
# Calculating mean average precision for gene: VPS36
# Calculating mean average precision for gene: VPS4B
# Calculating mean average precision for gene: VTA1
# Calculating mean average precision for gene: VTI1A
# Calculating mean average precision for gene: WDFY3
# Calculating mean average precision for gene: WDR45
# Calculating mean average precision for gene: WFDC8
# Calculating mean average precision for gene: WRAP53
# Calculating mean average precision for gene: XPC
# Calculating mean average precision for gene: XPO5
# Calculating mean average precision for gene: YWHAH
# Calculating mean average precision for gene: ZC3H8
# Calculating mean average precision for gene: ZC3HC1
# 0.0658561296859169
