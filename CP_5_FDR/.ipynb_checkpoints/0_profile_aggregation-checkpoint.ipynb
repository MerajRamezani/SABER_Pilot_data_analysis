# %%
import os
import pandas as pd
from pycytominer import feature_select,aggregate

# %%
# Set data input folder
# Before running notebook, download files described in README.md to this folder
input_folder = "../plate_level_profiles"

# Set output folder
output_folder = "outputs"
if not os.path.exists(output_folder):
    os.makedirs(output_folder, exist_ok=True)

# %%
# Load barcodes used in experiment
saber_library = pd.read_csv("../../SABER_Library_ngt_Included_Oligo_Sequences_Assiged.csv")
guide_list = list(saber_library['sgRNA'])
len(guide_list)
# Out:
# 2400

# %%
# Load normalized plate_level profiles, remove ghost guides, and merge 
M059K_plates = ['SABER_Plate_2','SABER_Plate_3','SABER_Plate_5','SABER_Plate_6']

M059K_list = []
for plate in M059K_plates:
    filename = f'20230601_6W_CP469_SABER_Pilot_M059K_guide_normalized_ALLBATCHES___{plate}___ALLWELLS.csv.gz'
    pre_M059K_df = pd.read_csv(os.path.join(input_folder, filename))
    pre_M059K_df = pre_M059K_df[pre_M059K_df["Metadata_Foci_Barcode_MatchedTo_Barcode"].isin(guide_list)]
    M059K_list.append(pre_M059K_df)

M059K_df = pd.concat(M059K_list)


M059K_df.head()
# Out:
#   Metadata_Foci_Barcode_MatchedTo_GeneCode  \
# 0                                    AARS2
# 1                                    AARS2
# 2                                    AARS2
# 3                                    AARS2
# 4                                   AARSD1
#
#   Metadata_Foci_Barcode_MatchedTo_Barcode  Cells_AreaShape_Center_X_x  \
# 0                    AAAGGCGGCCCTCACGGCCG                      3762.7
# 1                    AGCAAACTGGGGTCGCCGCG                      3622.0
# 2                    CCAACTTCTACGCAGAACAG                      3073.0
# 3                    GCTGAGCCAGTTCAGAAGCA                      3452.6
# 4                    ACCTCCGCTCCCAATCTACC                      2882.7
#
#    Cells_AreaShape_Center_Y_x  Cytoplasm_AreaShape_Center_X_x  \
# 0                      2837.6                          3761.3
# 1                      3298.2                          3628.3
# 2                      3049.7                          3073.4
# 3                      3734.9                          3451.7
# 4                      3341.6                          2885.1
#
#    Cytoplasm_AreaShape_Center_Y_x  Nuclei_AreaShape_Center_X_x  \
# 0                          2837.9                       3788.5
# 1                          3300.0                       3607.3
# 2                          3049.1                       3061.9
# 3                          3739.3                       3456.5
# 4                          3342.1                       2882.2
#
#    Nuclei_AreaShape_Center_Y_x  Cells_AreaShape_Area  \
# 0                       2834.8              0.610320
# 1                       3286.9             -0.012456
# 2                       3057.3             -0.680760
# 3                       3704.1             -0.414900
# 4                       3335.2              0.984540
#
#    Cells_AreaShape_BoundingBoxArea  ...  \
# 0                          1.07040  ...
# 1                          0.36358  ...
# 2                         -0.91050  ...
# 3                         -0.88976  ...
# 4                          1.01660  ...
#
#    Nuclei_Texture_Variance_btubulin_10_02_256  \
# 0                                     0.21645
# 1                                    -0.40061
# 2                                    -0.47984
# 3                                    -1.25930
# 4                                     0.48340
#
#    Nuclei_Texture_Variance_btubulin_10_03_256  \
# 0                                     0.33719
# 1                                    -0.35288
# 2                                    -0.24455
# 3                                    -1.15570
# 4                                     0.44318
#
#    Nuclei_Texture_Variance_btubulin_20_00_256  \
# 0                                     1.03590
# 1                                    -0.56428
# 2                                    -0.74271
# 3                                    -0.74271
# 4                                     1.30900
#
#    Nuclei_Texture_Variance_btubulin_20_01_256  \
# 0                                     0.49717
# 1                                    -0.52125
# 2                                    -0.63685
# 3                                    -0.63685
# 4                                     1.26180
#
#    Nuclei_Texture_Variance_btubulin_20_02_256  \
# 0                                     0.25361
# 1                                    -0.57874
# 2                                    -0.73178
# 3                                    -0.73178
# 4                                     1.40630
#
#    Nuclei_Texture_Variance_btubulin_20_03_256  \
# 0                                     0.18051
# 1                                    -0.37759
# 2                                    -0.60013
# 3                                    -0.60013
# 4                                     1.21250
#
#    Nuclei_Texture_Variance_btubulin_5_00_256  \
# 0                                    0.62282
# 1                                   -0.18640
# 2                                   -0.29418
# 3                                   -0.35732
# 4                                    0.52363
#
#    Nuclei_Texture_Variance_btubulin_5_01_256  \
# 0                                  -0.064759
# 1                                  -0.160370
# 2                                  -0.394800
# 3                                  -0.687200
# 4                                   0.444070
#
#    Nuclei_Texture_Variance_btubulin_5_02_256  \
# 0                                  -0.062812
# 1                                  -0.188990
# 2                                  -0.302220
# 3                                  -1.027000
# 4                                   0.449550
#
#    Nuclei_Texture_Variance_btubulin_5_03_256
# 0                                    1.25550
# 1                                   -0.44489
# 2                                   -0.30114
# 3                                   -0.91099
# 4                                    0.44109
#
# [5 rows x 10266 columns]

# %%
# subset the features to cp channels only
features = list(M059K_df.columns)

cp_channels = ['DNA','Phalloidin','Calnexin','COXIV','GM130']
SABER_only_channels = ['Catalase','btubulin','P65NFkb','Golgin97','LAMP1','PRSPS6','Syto9','TDP43','G3BP1']

for channel in SABER_only_channels:
    features = [feature for feature in features if channel not in feature]
    
print(len(features))
M059K_df = M059K_df[features]
M059K_df
# Out:
# 3813
#      Metadata_Foci_Barcode_MatchedTo_GeneCode  \
# 0                                       AARS2
# 1                                       AARS2
# 2                                       AARS2
# 3                                       AARS2
# 4                                      AARSD1
# ...                                       ...
# 2392                             nontargeting
# 2393                             nontargeting
# 2394                             nontargeting
# 2395                             nontargeting
# 2396                             nontargeting
#
#      Metadata_Foci_Barcode_MatchedTo_Barcode  Cells_AreaShape_Center_X_x  \
# 0                       AAAGGCGGCCCTCACGGCCG                      3762.7
# 1                       AGCAAACTGGGGTCGCCGCG                      3622.0
# 2                       CCAACTTCTACGCAGAACAG                      3073.0
# 3                       GCTGAGCCAGTTCAGAAGCA                      3452.6
# 4                       ACCTCCGCTCCCAATCTACC                      2882.7
# ...                                      ...                         ...
# 2392                    TAAGATCCGCGGGTGGCAAC                      3069.4
# 2393                    TCCCGGTTGGTGAACGATAC                      3267.8
# 2394                    TGCCGTGAAAAGACGCTGCG                      2710.2
# 2395                    TGGCCACGAATTCCGCCGCC                      2081.9
# 2396                    TTCAGCGAGTGTGACTAAGC                      2636.1
#
#       Cells_AreaShape_Center_Y_x  Cytoplasm_AreaShape_Center_X_x  \
# 0                         2837.6                          3761.3
# 1                         3298.2                          3628.3
# 2                         3049.7                          3073.4
# 3                         3734.9                          3451.7
# 4                         3341.6                          2885.1
# ...                          ...                             ...
# 2392                      3204.2                          3065.5
# 2393                      3474.6                          3267.0
# 2394                      3379.2                          2710.6
# 2395                      3295.6                          2082.6
# 2396                      3555.1                          2629.7
#
#       Cytoplasm_AreaShape_Center_Y_x  Nuclei_AreaShape_Center_X_x  \
# 0                             2837.9                       3788.5
# 1                             3300.0                       3607.3
# 2                             3049.1                       3061.9
# 3                             3739.3                       3456.5
# 4                             3342.1                       2882.2
# ...                              ...                          ...
# 2392                          3204.4                       3086.4
# 2393                          3473.7                       3281.3
# 2394                          3382.5                       2709.3
# 2395                          3294.2                       2079.7
# 2396                          3558.3                       2654.0
#
#       Nuclei_AreaShape_Center_Y_x  Cells_AreaShape_Area  \
# 0                          2834.8              0.610320
# 1                          3286.9             -0.012456
# 2                          3057.3             -0.680760
# 3                          3704.1             -0.414900
# 4                          3335.2              0.984540
# ...                           ...                   ...
# 2392                       3204.9              0.552470
# 2393                       3485.2             -0.843580
# 2394                       3355.9             -0.169340
# 2395                       3295.2              0.514700
# 2396                       3538.1             -0.253270
#
#       Cells_AreaShape_BoundingBoxArea  ...  \
# 0                            1.070400  ...
# 1                            0.363580  ...
# 2                           -0.910500  ...
# 3                           -0.889760  ...
# 4                            1.016600  ...
# ...                               ...  ...
# 2392                         0.697360  ...
# 2393                        -0.966190  ...
# 2394                        -0.113020  ...
# 2395                         0.091906  ...
# 2396                         0.014523  ...
#
#       Nuclei_Texture_Variance_Phalloidin_10_02_256  \
# 0                                        -0.268060
# 1                                        -0.097597
# 2                                        -0.258710
# 3                                        -0.060373
# 4                                        -0.053495
# ...                                            ...
# 2392                                     -0.310110
# 2393                                     -0.424410
# 2394                                     -0.051105
# 2395                                     -0.347880
# 2396                                      0.496620
#
#       Nuclei_Texture_Variance_Phalloidin_10_03_256  \
# 0                                        -0.270850
# 1                                        -0.043174
# 2                                        -0.259120
# 3                                        -0.092529
# 4                                        -0.042818
# ...                                            ...
# 2392                                     -0.239510
# 2393                                     -0.397240
# 2394                                     -0.076397
# 2395                                     -0.174260
# 2396                                      0.411120
#
#       Nuclei_Texture_Variance_Phalloidin_20_00_256  \
# 0                                         0.098870
# 1                                        -0.078298
# 2                                        -0.413680
# 3                                        -0.413680
# 4                                         0.578100
# ...                                            ...
# 2392                                     -0.185010
# 2393                                     -0.185010
# 2394                                     -0.185010
# 2395                                     -0.124180
# 2396                                     -0.185010
#
#       Nuclei_Texture_Variance_Phalloidin_20_01_256  \
# 0                                         0.126770
# 1                                        -0.056108
# 2                                        -0.106930
# 3                                        -0.106930
# 4                                         0.115420
# ...                                            ...
# 2392                                     -0.413680
# 2393                                     -0.413680
# 2394                                     -0.413680
# 2395                                     -0.244290
# 2396                                     -0.413680
#
#       Nuclei_Texture_Variance_Phalloidin_20_02_256  \
# 0                                         0.432540
# 1                                        -0.049872
# 2                                        -0.497460
# 3                                        -0.497460
# 4                                         0.714650
# ...                                            ...
# 2392                                     -0.320240
# 2393                                     -0.320240
# 2394                                     -0.320240
# 2395                                     -0.209500
# 2396                                     -0.320240
#
#       Nuclei_Texture_Variance_Phalloidin_20_03_256  \
# 0                                         0.940150
# 1                                        -0.127410
# 2                                        -0.495190
# 3                                        -0.495190
# 4                                         0.888450
# ...                                            ...
# 2392                                     -0.151410
# 2393                                     -0.151410
# 2394                                     -0.151410
# 2395                                     -0.096095
# 2396                                     -0.151410
#
#       Nuclei_Texture_Variance_Phalloidin_5_00_256  \
# 0                                        0.049743
# 1                                       -0.109070
# 2                                       -0.226750
# 3                                       -0.206060
# 4                                       -0.084462
# ...                                           ...
# 2392                                    -0.357850
# 2393                                    -0.274110
# 2394                                    -0.027866
# 2395                                    -0.352880
# 2396                                     0.561980
#
#       Nuclei_Texture_Variance_Phalloidin_5_01_256  \
# 0                                        0.086445
# 1                                       -0.095821
# 2                                       -0.214350
# 3                                       -0.120230
# 4                                       -0.082096
# ...                                           ...
# 2392                                    -0.349920
# 2393                                    -0.262160
# 2394                                     0.006505
# 2395                                    -0.273740
# 2396                                     0.476380
#
#       Nuclei_Texture_Variance_Phalloidin_5_02_256  \
# 0                                        0.081901
# 1                                       -0.072852
# 2                                       -0.234250
# 3                                       -0.156020
# 4                                       -0.088276
# ...                                           ...
# 2392                                    -0.341500
# 2393                                    -0.228140
# 2394                                    -0.045215
# 2395                                    -0.249230
# 2396                                     0.533320
#
#       Nuclei_Texture_Variance_Phalloidin_5_03_256
# 0                                       -0.193190
# 1                                       -0.045826
# 2                                       -0.281360
# 3                                       -0.125760
# 4                                       -0.078953
# ...                                           ...
# 2392                                    -0.401550
# 2393                                    -0.278850
# 2394                                     0.113520
# 2395                                    -0.380720
# 2396                                     0.464620
#
# [9594 rows x 3813 columns]

# %%
# Perform feature selection on merged profiles
M059K_feature_selected_df = feature_select(
            profiles=M059K_df,
            features='infer',
            samples='all',
            operation=['variance_threshold','correlation_threshold','drop_na_columns','blocklist','drop_outliers'],
            na_cutoff= 0,
            corr_threshold=0.9,
            outlier_cutoff=100
        )

M059K_feature_selected_df.to_csv(os.path.join(output_folder,'20230601_6W_CP469_SABER_Pilot_M059K_guide_normalized_feature_select_merged_ALLBATCHES___ALLWELLS_cp_features.csv.gz'))

# %%
# Perform median aggregation on profiles
M059K_feature_selected_median_df= aggregate(
                    population_df=M059K_feature_selected_df, 
                    strata=['Metadata_Foci_Barcode_MatchedTo_GeneCode' ,'Metadata_Foci_Barcode_MatchedTo_Barcode'], 
                    features='infer', 
                    operation='median' 
                    )

M059K_feature_selected_median_df.to_csv(os.path.join(output_folder,'20230601_6W_CP469_SABER_Pilot_M059K_guide_normalized_feature_select_median_merged_ALLBATCHES___ALLWELLS_cp_features.csv.gz'),index = False)

# %% [markdown]
# **Gene level aggregation**

# %%
# List files to undergo gene level aggregation
file_list = ["20230601_6W_CP469_SABER_Pilot_M059K_guide_normalized_feature_select_median_merged_ALLBATCHES___ALLWELLS_cp_features.csv.gz"]

# Set aggregation parameters for gene level aggregation
aggregate_columns = ['Metadata_Foci_Barcode_MatchedTo_GeneCode']
aggregate_features = 'infer'
aggregate_operation = 'median'

# %%
# Perform profile aggregation
for profile_file in file_list:
    print (f"Now loading {profile_file}")
    df = pd.read_csv(os.path.join(output_folder,profile_file))
    df = df[df["Metadata_Foci_Barcode_MatchedTo_Barcode"].isin(guide_list)]

    print (f"Now aggregating.")
    gene_df = aggregate(
            population_df=df,
            strata=aggregate_columns,
            features=aggregate_features,
            operation=aggregate_operation,
            )

    print (f"Now saving aggregated file.")
    agg_file_name = f"{profile_file.split('.',1)[0]}_gene_aggregated.{profile_file.split('.',1)[1]}"
    gene_df.to_csv(os.path.join(output_folder, agg_file_name), index=False)
# Out:
# Now loading 20230601_6W_CP469_SABER_Pilot_M059K_guide_normalized_feature_select_median_merged_ALLBATCHES___ALLWELLS_cp_features.csv.gz
# Now aggregating.
# Now saving aggregated file.

# %%
M059K_feature_selected_median_df
# Out:
#      Metadata_Foci_Barcode_MatchedTo_GeneCode  \
# 0                                       AARS2
# 1                                       AARS2
# 2                                       AARS2
# 3                                       AARS2
# 4                                      AARSD1
# ...                                       ...
# 2395                             nontargeting
# 2396                             nontargeting
# 2397                             nontargeting
# 2398                             nontargeting
# 2399                             nontargeting
#
#      Metadata_Foci_Barcode_MatchedTo_Barcode  \
# 0                       AAAGGCGGCCCTCACGGCCG
# 1                       AGCAAACTGGGGTCGCCGCG
# 2                       CCAACTTCTACGCAGAACAG
# 3                       GCTGAGCCAGTTCAGAAGCA
# 4                       ACCTCCGCTCCCAATCTACC
# ...                                      ...
# 2395                    TAAGATCCGCGGGTGGCAAC
# 2396                    TCCCGGTTGGTGAACGATAC
# 2397                    TGCCGTGAAAAGACGCTGCG
# 2398                    TGGCCACGAATTCCGCCGCC
# 2399                    TTCAGCGAGTGTGACTAAGC
#
#       Cells_AreaShape_CentralMoment_0_1  Cells_AreaShape_CentralMoment_0_3  \
# 0                              0.033501                          -0.021708
# 1                              0.098789                          -0.041051
# 2                              0.080462                          -0.007381
# 3                             -0.115877                          -0.095393
# 4                              0.106199                          -0.002299
# ...                                 ...                                ...
# 2395                          -0.093411                          -0.006135
# 2396                          -0.074922                          -0.016022
# 2397                          -0.197905                          -0.024100
# 2398                           0.083609                           0.003866
# 2399                          -0.195768                          -0.089638
#
#       Cells_AreaShape_CentralMoment_1_0  Cells_AreaShape_CentralMoment_1_1  \
# 0                             -0.446427                          -0.052055
# 1                              0.013143                           0.027802
# 2                             -0.019076                           0.096305
# 3                             -0.234975                          -0.022434
# 4                              0.005447                          -0.032071
# ...                                 ...                                ...
# 2395                          -0.025522                           0.018110
# 2396                           0.008407                           0.011823
# 2397                           0.051483                           0.007274
# 2398                          -0.022012                           0.139262
# 2399                          -0.152896                          -0.146448
#
#       Cells_AreaShape_CentralMoment_1_2  Cells_AreaShape_CentralMoment_1_3  \
# 0                             -0.106097                          -0.035181
# 1                              0.000183                           0.006994
# 2                              0.049998                           0.033392
# 3                              0.000537                          -0.001022
# 4                              0.010073                           0.005625
# ...                                 ...                                ...
# 2395                           0.037509                          -0.003599
# 2396                          -0.005692                           0.014658
# 2397                           0.017820                           0.015592
# 2398                           0.010856                           0.014981
# 2399                           0.009163                           0.012537
#
#       Cells_AreaShape_CentralMoment_2_1  Cells_AreaShape_CentralMoment_2_2  \
# 0                             -0.024508                           0.101165
# 1                              0.014238                          -0.307540
# 2                              0.008300                          -0.290030
# 3                             -0.056283                          -0.161884
# 4                              0.008212                           0.558170
# ...                                 ...                                ...
# 2395                          -0.075485                           0.138834
# 2396                           0.006559                          -0.107477
# 2397                          -0.001664                          -0.244840
# 2398                          -0.107854                          -0.147185
# 2399                           0.015239                           0.035347
#
#       ...  Nuclei_Texture_SumVariance_Calnexin_20_03_256  \
# 0     ...                                      -0.283260
# 1     ...                                      -0.479160
# 2     ...                                      -0.479160
# 3     ...                                      -0.381090
# 4     ...                                       1.102550
# ...   ...                                            ...
# 2395  ...                                      -0.094215
# 2396  ...                                      -0.166074
# 2397  ...                                      -0.286660
# 2398  ...                                      -0.366595
# 2399  ...                                      -0.023025
#
#       Nuclei_Texture_SumVariance_Calnexin_5_02_256  \
# 0                                         1.223165
# 1                                         0.042645
# 2                                        -0.268070
# 3                                        -0.364134
# 4                                         0.325770
# ...                                            ...
# 2395                                     -0.086080
# 2396                                      0.527320
# 2397                                      0.017660
# 2398                                     -0.088162
# 2399                                     -0.040278
#
#       Nuclei_Texture_SumVariance_DNA_10_01_256  \
# 0                                    -0.861290
# 1                                     0.355875
# 2                                    -0.216838
# 3                                    -0.294380
# 4                                     0.798840
# ...                                        ...
# 2395                                  0.050148
# 2396                                  0.254985
# 2397                                 -0.006520
# 2398                                  0.008927
# 2399                                 -0.138930
#
#       Nuclei_Texture_SumVariance_DNA_20_01_256  \
# 0                                     0.045650
# 1                                    -0.529805
# 2                                    -0.529805
# 3                                    -0.467000
# 4                                     1.244500
# ...                                        ...
# 2395                                  0.186640
# 2396                                 -0.427635
# 2397                                 -0.358925
# 2398                                 -0.427635
# 2399                                  0.146645
#
#       Nuclei_Texture_SumVariance_DNA_20_03_256  \
# 0                                    -0.058530
# 1                                    -0.475970
# 2                                    -0.486250
# 3                                    -0.367030
# 4                                     1.149600
# ...                                        ...
# 2395                                 -0.079335
# 2396                                 -0.367030
# 2397                                 -0.279415
# 2398                                 -0.350825
# 2399                                 -0.085270
#
#       Nuclei_Texture_SumVariance_GM130_20_01_256  \
# 0                                      -0.210587
# 1                                      -0.619375
# 2                                      -0.619375
# 3                                      -0.376080
# 4                                       1.139140
# ...                                          ...
# 2395                                    0.047555
# 2396                                   -0.376080
# 2397                                    0.139215
# 2398                                   -0.376080
# 2399                                    0.165280
#
#       Nuclei_Texture_SumVariance_GM130_5_00_256  \
# 0                                     -0.240745
# 1                                     -0.188795
# 2                                     -0.009330
# 3                                     -0.722730
# 4                                      0.281992
# ...                                         ...
# 2395                                  -0.066887
# 2396                                   0.019385
# 2397                                  -0.016525
# 2398                                   0.215435
# 2399                                  -0.007525
#
#       Nuclei_Texture_SumVariance_Phalloidin_10_02_256  \
# 0                                            0.081160
# 1                                           -0.034064
# 2                                           -0.114787
# 3                                           -0.246800
# 4                                           -0.006721
# ...                                               ...
# 2395                                         0.027325
# 2396                                        -0.172278
# 2397                                         0.031936
# 2398                                        -0.196010
# 2399                                         0.306105
#
#       Nuclei_Texture_SumVariance_Phalloidin_20_01_256  \
# 0                                           -0.199070
# 1                                           -0.397135
# 2                                           -0.397135
# 3                                           -0.288600
# 4                                            0.633935
# ...                                               ...
# 2395                                        -0.005835
# 2396                                        -0.281090
# 2397                                        -0.157765
# 2398                                        -0.281090
# 2399                                        -0.058160
#
#       Nuclei_Texture_Variance_Calnexin_20_00_256
# 0                                      -0.199375
# 1                                      -0.332470
# 2                                      -0.447315
# 3                                      -0.447315
# 4                                       0.934645
# ...                                          ...
# 2395                                   -0.128360
# 2396                                   -0.218643
# 2397                                   -0.302650
# 2398                                   -0.283045
# 2399                                   -0.215250
#
# [2400 rows x 2139 columns]
