# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
import seaborn as sns
import os
import json
from itertools import permutations
from sklearn.decomposition import PCA

np.random.seed(42)

# %matplotlib inline

# %%
# Set data input folder
input_folder = "inputs"

# Set output folder, subfolder
output_folder = "outputs"
if not os.path.exists(output_folder):
    os.makedirs(output_folder, exist_ok=True)

# %%
whole_cell_hits = pd.read_csv(os.path.join(output_folder,'HeLa_SABER_plate_level_median_per_feat_sig_genes_1_FDR_whole_cell_hits.csv'))
comp_spec_hits = pd.read_csv(os.path.join(output_folder,'HeLa_SABER_plate_level_median_per_feat_sig_genes_1_FDR_compartment_specific_hits.csv'))
all_hits = pd.concat([whole_cell_hits,comp_spec_hits])
all_hits
# Out:
#         Gene    DNA  Phalloidin    WGA   ConA  Catalase  btubulin  Calnexin  \
# 0      ABCF1    9.0        25.0   14.0   20.0       8.0      27.0      19.0
# 1      ACTR2  129.0       111.0  100.0  103.0      80.0      94.0     104.0
# 2      ACTR3   95.0        94.0   93.0   74.0      62.0      76.0      81.0
# 3      ALG13   67.0        43.0   55.0  100.0      24.0      44.0      57.0
# 4       ALG5   17.0        21.0   38.0   96.0       3.0      15.0      15.0
# ..       ...    ...         ...    ...    ...       ...       ...       ...
# 73  TMEM106B    2.0         9.0   14.0    3.0       0.0       2.0       3.0
# 74    UBQLN2    1.0        11.0    9.0    2.0       0.0       6.0       2.0
# 75      UCP2    5.0         4.0    5.0    2.0       6.0       8.0      10.0
# 76      USP1    4.0         8.0   18.0    8.0       4.0       0.0       3.0
# 77    ZNF131   21.0         5.0   16.0    5.0       2.0       3.0       8.0
#
#     NfKb  COXIV  LAMP1  PRSP6  Syto9  TDP43  G3BP1  GM130     Sum
# 0   25.0   38.0   26.0   34.0   16.0   12.0   24.0   19.0   230.0
# 1   93.0  120.0   65.0   80.0  158.0   98.0   79.0   94.0  1196.0
# 2   77.0  110.0   66.0   59.0  133.0   73.0   69.0   75.0   975.0
# 3   38.0   90.0   85.0   94.0   78.0   53.0   29.0   35.0   680.0
# 4   22.0   26.0  121.0   19.0   15.0   27.0    2.0    7.0   328.0
# ..   ...    ...    ...    ...    ...    ...    ...    ...     ...
# 73   3.0    4.0   61.0    0.0    4.0    6.0    0.0    1.0    76.0
# 74   5.0   23.0   16.0   20.0    7.0    4.0    1.0    2.0    76.0
# 75  23.0    7.0   10.0    6.0   12.0    7.0   19.0    9.0    95.0
# 76   8.0   17.0    4.0    7.0   24.0   15.0    3.0    5.0    78.0
# 77  12.0   28.0    8.0    9.0   10.0    9.0    8.0    8.0    99.0
#
# [384 rows x 17 columns]

# %%
selected_targets_list = ['TARDBP','COX4I1','CANX','LAMP1','RPS6','TUBB4B','GOLGA2','CAT']
selected_targets_df = all_hits[all_hits['Gene'].isin(selected_targets_list)].set_index('Gene').drop('Sum',axis=1)
fig, ax = plt.subplots(figsize=(13,6))
sns.lineplot(selected_targets_df.T,ax=ax)
fig.savefig(os.path.join(output_folder,'figure_panels','HeLa_SABER_targeted_channels_ditribution.png'), dpi=300,facecolor='w', edgecolor='w', bbox_inches='tight')
plt.show()

# %% [markdown]
# ##
